# %%
# General imports
import numpy as np

# Pre-defined ansatz circuit and operator class for Hamiltonian
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp

# SciPy minimizer routine
from scipy.optimize import minimize

# Plotting functions
import matplotlib.pyplot as plt

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
 
# Save an IBM Quantum account and set it as your default account.
# QiskitRuntimeService.save_account(channel="ibm_quantum", token="3938ec2167453e68ce3646104524ba97ba6ac764a519f4d27ae60605457a2573c9c1ae623c61938e759da0b428b13897be8a891a6740628557d539870d873c48")
 
# Load saved credentials
# service = QiskitRuntimeService()

service = QiskitRuntimeService(channel="ibm_quantum", token="20087d51312815e73fc41da774aae12d7fc0cb5560cbf289e0a4e34ded4072d4050be4137820956956a33e80c0b9b13c0ce3d7d74d2d34777e92230420695103")

# 3938ec2167453e68ce3646104524ba97ba6ac764a519f4d27ae60605457a2573c9c1ae623c61938e759da0b428b13897be8a891a6740628557d539870d873c48

# %%
# runtime imports
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator

# To run on hardware, select the backend with the fewest number of jobs in the queue
# service = QiskitRuntimeService(channel="ibm_quantum")
backend = service.least_busy(operational=True, simulator=False)
backend.name
# Out:
# 'ibm_kyoto'

# %%
import qiskit_ibm_runtime

qiskit_ibm_runtime.version.get_version_info()
# Out:
# '0.23.0'

# %% [markdown]
# ## Step 1: Map classical inputs to a quantum problem

# %%
# hamiltonian = SparsePauliOp.from_list(
#     [("YZ", 0.3980), ("ZI", -0.3980), ("ZZ", -0.0113), ("XX", 0.1810)]
# )

hamiltonian = SparsePauliOp.from_list(
                [("IIII", -0.0996), 
                ("IIIZ", 0.1711), 
                ("IIZI", 0.1711), 
                ("IZII", -0.2225), 
                ("ZIII", -0.2225), 
                ("IIZZ", 0.1686), 
                ("IZIZ", 0.1205), 
                ("ZIIZ", 0.1658), 
                ("IZZI", 0.1658), 
                ("ZIZI", 0.1205), 
                ("ZZII", 0.1743), 
                ("XYYX", 0.0453), 
                ("YXXY", 0.0453), 
                ("YYXX", -0.0453), 
                ("XXYY", -0.0453)]
            )

# hamiltonian = SparsePauliOp.from_list(
#     [("IIII", -0.81054), 
#      ("IZIZ", 0.16614), 
#      ("ZIZI", 0.16892), 
#      ("ZIII", 0.17218), 
#      ("IIZI", 0.17218), 
#      ("IZII", -0.22573), 
#      ("IIIZ", -0.22573), 
#      ("ZZII", 0.12091), 
#      ("IIZZ", 0.12091), 
#      ("ZIIZ", 0.166145), 
#      ("IZZI", 0.166145), 
#      ("YYYY", 0.04523), 
#      ("XXYY", 0.04523), 
#      ("YYXX", 0.04523), 
#      ("XXXX", 0.04523)]
# )

# %%
hamiltonian
# Out:
# SparsePauliOp(['IIII', 'IIIZ', 'IIZI', 'IZII', 'ZIII', 'IIZZ', 'IZIZ', 'ZIIZ', 'IZZI', 'ZIZI', 'ZZII', 'XYYX', 'YXXY', 'YYXX', 'XXYY'],
#               coeffs=[-0.0996+0.j,  0.1711+0.j,  0.1711+0.j, -0.2225+0.j, -0.2225+0.j,
#   0.1686+0.j,  0.1205+0.j,  0.1658+0.j,  0.1658+0.j,  0.1205+0.j,
#   0.1743+0.j,  0.0453+0.j,  0.0453+0.j, -0.0453+0.j, -0.0453+0.j])

# %%
from qiskit.circuit.library import TwoLocal

entangler_map = [[0, 1], [1, 2], [2,3], [3,0]]  # entangle the first and last two-way
ansatz = TwoLocal(hamiltonian.num_qubits, 'ry', 'cx', entangler_map, reps=1, skip_final_rotation_layer=True)

ansatz.decompose().draw("mpl", style="iqp")

# %%
num_params = ansatz.num_parameters
num_params
# Out:
# 4

# %% [markdown]
# ## Step 2: Optimize problem for quantum execution.

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(ansatz)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# ## Step 3: Execute using Qiskit Primitives.

# %% [markdown]
# ### COBYLA Optimizer

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

def cost_func(params, ansatz, hamiltonian, estimator):
    """Return estimate of energy from estimator

    Parameters:
        params (ndarray): Array of ansatz parameters
        ansatz (QuantumCircuit): Parameterized ansatz circuit
        hamiltonian (SparsePauliOp): Operator representation of Hamiltonian
        estimator (EstimatorV2): Estimator primitive instance
        cost_history_dict: Dictionary for storing intermediate results

    Returns:
        float: Energy estimate
    """
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")

    return energy

# %%
x0 = 2 * np.pi * np.random.random(num_params)
x0
# Out:
# array([5.83954476, 2.86529012, 3.00693627, 2.64136916])

# %%
with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    estimator.options.default_shots = 200

    res = minimize(
        cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method='cobyla',
    )
# Out:
# Iters. done: 1 [Current cost: -0.40750772007942027]
# Iters. done: 2 [Current cost: -0.40430386680852415]
# Iters. done: 3 [Current cost: -0.38115599153815927]
# Iters. done: 4 [Current cost: -0.40140428743583334]
# Iters. done: 5 [Current cost: -0.43910528637460716]
# Iters. done: 6 [Current cost: -0.29432232255917784]
# Iters. done: 7 [Current cost: -0.41153977039817746]
# Iters. done: 8 [Current cost: -0.4091438192283841]
# Iters. done: 9 [Current cost: -0.41787588225456346]
# Iters. done: 10 [Current cost: -0.4142119003044943]
# Iters. done: 11 [Current cost: -0.3890838738741376]
# Iters. done: 12 [Current cost: -0.38363826705241044]
# Iters. done: 13 [Current cost: -0.42978630621227165]
# Iters. done: 14 [Current cost: -0.4388331215003457]
# Iters. done: 15 [Current cost: -0.4332310898139571]
# Iters. done: 16 [Current cost: -0.3955273611119217]
# Iters. done: 17 [Current cost: -0.41887298047505983]
# Iters. done: 18 [Current cost: -0.4140174915747389]
# Iters. done: 19 [Current cost: -0.4088439827664784]
# Iters. done: 20 [Current cost: -0.3869737681932508]
# Iters. done: 21 [Current cost: -0.4344443649362075]
# capi_return is NULL
# Call-back cb_calcfc_in__cobyla__user__routines failed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[73], line 5
#       2 estimator = Estimator(session=session)
#       3 estimator.options.default_shots = 200
# ----> 5 res = minimize(
#       6     cost_func,
#       7     x0,
#       8     args=(ansatz_isa, hamiltonian_isa, estimator),
#       9     method='cobyla',
#      10 )
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_minimize.py:719, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     716     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     717                         **options)
#     718 elif meth == 'cobyla':
# --> 719     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     720                            bounds=bounds, **options)
#     721 elif meth == 'slsqp':
#     722     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     723                           constraints, callback=callback, **options)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:293, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     290         callback(np.copy(x))
#     292 info = np.zeros(4, np.float64)
# --> 293 xopt, info = cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     294                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     295                               dinfo=info, callback=wrapped_callback)
#     297 if info[3] > catol:
#     298     # Check constraint violation
#     299     info[0] = 4
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:281, in _minimize_cobyla.<locals>.calcfc(x, con)
#     280 def calcfc(x, con):
# --> 281     f = sf.fun(x)
#     282     i = 0
#     283     for size, c in izip(cons_lengths, constraints):
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:278, in ScalarFunction.fun(self, x)
#     276 if not np.array_equal(x, self.x):
#     277     self._update_x_impl(x)
# --> 278 self._update_fun()
#     279 return self.f
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# Cell In[71], line 21, in cost_func(params, ansatz, hamiltonian, estimator)
#       8 """Return estimate of energy from estimator
#       9
#      10 Parameters:
#    (...)
#      18     float: Energy estimate
#      19 """
#      20 pub = (ansatz, [hamiltonian], [params])
# ---> 21 result = estimator.run(pubs=[pub]).result()
#      22 energy = result[0].data.evs[0]
#      24 cost_history_dict["iters"] += 1
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/estimator.py:151, in EstimatorV2.run(self, pubs, precision)
#     137 """Submit a request to the estimator primitive.
#     138
#     139 Args:
#    (...)
#     148
#     149 """
#     150 coerced_pubs = [EstimatorPub.coerce(pub, precision) for pub in pubs]
# --> 151 return self._run(coerced_pubs)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/base_primitive.py:163, in BasePrimitiveV2._run(self, pubs)
#     160 logger.info("Submitting job using options %s", primitive_options)
#     162 if self._session:
# --> 163     return self._session.run(
#     164         program_id=self._program_id(),
#     165         inputs=primitive_inputs,
#     166         options=runtime_options,
#     167         callback=options_dict.get("environment", {}).get("callback", None),
#     168         result_decoder=DEFAULT_DECODERS.get(self._program_id()),
#     169     )
#     171 if self._backend:
#     172     runtime_options["backend"] = self._backend
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/session.py:43, in _active_session.<locals>._wrapper(self, *args, **kwargs)
#      41 if not self._active:
#      42     raise RuntimeError("The session is closed.")
# ---> 43 return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/session.py:201, in Session.run(self, program_id, inputs, options, callback, result_decoder)
#     198 options["backend"] = self._backend
#     200 if isinstance(self._service, QiskitRuntimeService):
# --> 201     job = self._service.run(
#     202         program_id=program_id,  # type: ignore[arg-type]
#     203         options=options,
#     204         inputs=inputs,
#     205         session_id=self._session_id,
#     206         start_session=False,
#     207         callback=callback,
#     208         result_decoder=result_decoder,
#     209     )
#     211     if self._backend is None:
#     212         self._backend = job.backend()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:859, in QiskitRuntimeService.run(self, program_id, inputs, options, callback, result_decoder, session_id, start_session)
#     857 version = inputs.get("version", 1) if inputs else 1
#     858 try:
# --> 859     response = self._api_client.program_run(
#     860         program_id=program_id,
#     861         backend_name=qrt_options.get_backend_name(),
#     862         params=inputs,
#     863         image=qrt_options.image,
#     864         hgp=hgp_name,
#     865         log_level=qrt_options.log_level,
#     866         session_id=session_id,
#     867         job_tags=qrt_options.job_tags,
#     868         max_execution_time=qrt_options.max_execution_time,
#     869         start_session=start_session,
#     870         session_time=qrt_options.session_time,
#     871         channel_strategy=None
#     872         if self._channel_strategy == "default"
#     873         else self._channel_strategy,
#     874     )
#     875     if self._channel == "ibm_quantum":
#     876         messages = response.get("messages")
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/api/clients/runtime.py:87, in RuntimeClient.program_run(self, program_id, backend_name, params, image, hgp, log_level, session_id, job_tags, max_execution_time, start_session, session_time, channel_strategy)
#      85     hub, group, project = from_instance_format(hgp)
#      86     hgp_dict = {"hub": hub, "group": group, "project": project}
# ---> 87 return self._api.program_run(
#      88     program_id=program_id,
#      89     backend_name=backend_name,
#      90     params=params,
#      91     image=image,
#      92     log_level=log_level,
#      93     session_id=session_id,
#      94     job_tags=job_tags,
#      95     max_execution_time=max_execution_time,
#      96     start_session=start_session,
#      97     session_time=session_time,
#      98     channel_strategy=channel_strategy,
#      99     **hgp_dict,
#     100 )
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/api/rest/runtime.py:128, in Runtime.program_run(self, program_id, backend_name, params, image, hub, group, project, log_level, session_id, job_tags, max_execution_time, start_session, session_time, channel_strategy)
#     126     payload["channel_strategy"] = channel_strategy
#     127 data = json.dumps(payload, cls=RuntimeEncoder)
# --> 128 return self.session.post(url, data=data, timeout=900).json()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/api/session.py:328, in RetrySession.request(self, method, url, bare, **kwargs)
#     326 try:
#     327     self._log_request_info(final_url, method, kwargs)
# --> 328     response = super().request(method, final_url, headers=headers, **kwargs)
#     329     response.raise_for_status()
#     330 except RequestException as ex:
#     331     # Wrap the requests exceptions into a IBM Q custom one, for
#     332     # compatibility.
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    estimator.options.default_shots = 2048

    res = minimize(
        cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method='cobyla',
    )
# Out:
# Iters. done: 22 [Current cost: -0.40883851378836134]
# Iters. done: 23 [Current cost: -0.4335870723794597]
# Iters. done: 24 [Current cost: -0.36804651200518373]
# Iters. done: 25 [Current cost: -0.3976392364270078]
# Iters. done: 26 [Current cost: -0.42917379342577205]
# Iters. done: 27 [Current cost: -0.326573735312314]
# Iters. done: 28 [Current cost: -0.37395132177164025]
# Iters. done: 29 [Current cost: -0.42268113376689803]
# Iters. done: 30 [Current cost: -0.42273826278225807]
# Iters. done: 31 [Current cost: -0.42704085097559463]
# Iters. done: 32 [Current cost: -0.43087224837760574]
# Iters. done: 33 [Current cost: -0.3959614693359255]
# Iters. done: 34 [Current cost: -0.427621186632811]
# Iters. done: 35 [Current cost: -0.420096178139079]
# Iters. done: 36 [Current cost: -0.42962103571224874]
# Iters. done: 37 [Current cost: -0.42447833522939526]
# Iters. done: 38 [Current cost: -0.4330772089526411]
# Iters. done: 39 [Current cost: -0.4186620556001528]
# Iters. done: 40 [Current cost: -0.4108742890455359]
# Iters. done: 41 [Current cost: -0.40755787938940224]
# Iters. done: 42 [Current cost: -0.4322515711472405]
# Iters. done: 43 [Current cost: -0.4243339018353915]
# Iters. done: 44 [Current cost: -0.4390361612374505]
# Iters. done: 45 [Current cost: -0.41966801163066453]
# capi_return is NULL
# Call-back cb_calcfc_in__cobyla__user__routines failed.
# ---------------------------------------------------------------------------
# IBMRuntimeError                           Traceback (most recent call last)
# Cell In[74], line 5
#       2 estimator = Estimator(session=session)
#       3 estimator.options.default_shots = 2048
# ----> 5 res = minimize(
#       6     cost_func,
#       7     x0,
#       8     args=(ansatz_isa, hamiltonian_isa, estimator),
#       9     method='cobyla',
#      10 )
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_minimize.py:719, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     716     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     717                         **options)
#     718 elif meth == 'cobyla':
# --> 719     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     720                            bounds=bounds, **options)
#     721 elif meth == 'slsqp':
#     722     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     723                           constraints, callback=callback, **options)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:293, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     290         callback(np.copy(x))
#     292 info = np.zeros(4, np.float64)
# --> 293 xopt, info = cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     294                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     295                               dinfo=info, callback=wrapped_callback)
#     297 if info[3] > catol:
#     298     # Check constraint violation
#     299     info[0] = 4
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:281, in _minimize_cobyla.<locals>.calcfc(x, con)
#     280 def calcfc(x, con):
# --> 281     f = sf.fun(x)
#     282     i = 0
#     283     for size, c in izip(cons_lengths, constraints):
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:278, in ScalarFunction.fun(self, x)
#     276 if not np.array_equal(x, self.x):
#     277     self._update_x_impl(x)
# --> 278 self._update_fun()
#     279 return self.f
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# Cell In[71], line 21, in cost_func(params, ansatz, hamiltonian, estimator)
#       8 """Return estimate of energy from estimator
#       9
#      10 Parameters:
#    (...)
#      18     float: Energy estimate
#      19 """
#      20 pub = (ansatz, [hamiltonian], [params])
# ---> 21 result = estimator.run(pubs=[pub]).result()
#      22 energy = result[0].data.evs[0]
#      24 cost_history_dict["iters"] += 1
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/estimator.py:151, in EstimatorV2.run(self, pubs, precision)
#     137 """Submit a request to the estimator primitive.
#     138
#     139 Args:
#    (...)
#     148
#     149 """
#     150 coerced_pubs = [EstimatorPub.coerce(pub, precision) for pub in pubs]
# --> 151 return self._run(coerced_pubs)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/base_primitive.py:163, in BasePrimitiveV2._run(self, pubs)
#     160 logger.info("Submitting job using options %s", primitive_options)
#     162 if self._session:
# --> 163     return self._session.run(
#     164         program_id=self._program_id(),
#     165         inputs=primitive_inputs,
#     166         options=runtime_options,
#     167         callback=options_dict.get("environment", {}).get("callback", None),
#     168         result_decoder=DEFAULT_DECODERS.get(self._program_id()),
#     169     )
#     171 if self._backend:
#     172     runtime_options["backend"] = self._backend
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/session.py:43, in _active_session.<locals>._wrapper(self, *args, **kwargs)
#      41 if not self._active:
#      42     raise RuntimeError("The session is closed.")
# ---> 43 return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/session.py:201, in Session.run(self, program_id, inputs, options, callback, result_decoder)
#     198 options["backend"] = self._backend
#     200 if isinstance(self._service, QiskitRuntimeService):
# --> 201     job = self._service.run(
#     202         program_id=program_id,  # type: ignore[arg-type]
#     203         options=options,
#     204         inputs=inputs,
#     205         session_id=self._session_id,
#     206         start_session=False,
#     207         callback=callback,
#     208         result_decoder=result_decoder,
#     209     )
#     211     if self._backend is None:
#     212         self._backend = job.backend()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:884, in QiskitRuntimeService.run(self, program_id, inputs, options, callback, result_decoder, session_id, start_session)
#     882     if ex.status_code == 404:
#     883         raise RuntimeProgramNotFound(f"Program not found: {ex.message}") from None
# --> 884     raise IBMRuntimeError(f"Failed to run program: {ex}") from None
#     885 backend = (
#     886     self.backend(name=response["backend"], instance=hgp_name)
#     887     if response["backend"]
#     888     else qrt_options.get_backend_name()
#     889 )
#     891 if version == 2:
#
# IBMRuntimeError: 'Failed to run program: \'400 Client Error: Bad Request for url: https://api.quantum.ibm.com/runtime/jobs. {"errors":[{"code":1217,"message":"Session has been closed.","solution":"Reduce time between submitting subsequent jobs in a session.","more_info":"https://docs.quantum-computing.ibm.com/errors"}]}\''

# %% [markdown]
# ### Nakanishi Fuji Todo Optimizer

# %%
from nftopt import nakanishi_fujii_todo

with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    estimator.options.default_shots = 200

    res = minimize(
        cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method=nakanishi_fujii_todo,
    )
# Out:
# Iters. done: 46 [Current cost: -0.41388371120433765]
# Iters. done: 47 [Current cost: -0.439309545198593]
# Iters. done: 48 [Current cost: -0.3908839690362146]
# Iters. done: 49 [Current cost: -0.3461547476384264]
# Iters. done: 50 [Current cost: -0.2291297500592317]
# Iters. done: 51 [Current cost: -0.3005408940779945]
# Iters. done: 52 [Current cost: -0.23843496601599182]
# Iters. done: 53 [Current cost: -0.37534770725432265]
# Iters. done: 54 [Current cost: -0.2838801682729776]
# Iters. done: 55 [Current cost: -0.38328018516898005]
# Iters. done: 56 [Current cost: -0.4338667440353671]
# Iters. done: 57 [Current cost: -0.16333194763035197]
# Iters. done: 58 [Current cost: -0.23046090699787442]
# Iters. done: 59 [Current cost: -0.3712474848186935]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[75], line 7
#       4 estimator = Estimator(session=session)
#       5 estimator.options.default_shots = 200
# ----> 7 res = minimize(
#       8     cost_func,
#       9     x0,
#      10     args=(ansatz_isa, hamiltonian_isa, estimator),
#      11     method=nakanishi_fujii_todo,
#      12 )
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_minimize.py:636, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     630         options.setdefault('barrier_tol', tol)
#     632 if meth == '_custom':
#     633     # custom method called before bounds and constraints are 'standardised'
#     634     # custom method should be able to accept whatever bounds/constraints
#     635     # are provided to it.
# --> 636     return method(fun, x0, args=args, jac=jac, hess=hess, hessp=hessp,
#     637                   bounds=bounds, constraints=constraints,
#     638                   callback=callback, **options)
#     640 constraints = standardize_constraints(constraints, x0, meth)
#     642 remove_vars = False
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/nftopt/nft.py:85, in nakanishi_fujii_todo(fun, x0, args, maxfev, reset_interval, eps, callback, **_)
#      83 p = np.copy(x0)
#      84 p[idx] = x0[idx] - np.pi / 2
# ---> 85 z3 = fun(p, *args)
#      86 funcalls += 1
#      88 z2 = z1 + z3 - z0
#
# Cell In[71], line 21, in cost_func(params, ansatz, hamiltonian, estimator)
#       8 """Return estimate of energy from estimator
#       9
#      10 Parameters:
#    (...)
#      18     float: Energy estimate
#      19 """
#      20 pub = (ansatz, [hamiltonian], [params])
# ---> 21 result = estimator.run(pubs=[pub]).result()
#      22 energy = result[0].data.evs[0]
#      24 cost_history_dict["iters"] += 1
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/runtime_job_v2.py:135, in RuntimeJobV2.result(self, timeout, decoder)
#     120 """Return the results of the job.
#     121
#     122 Args:
#    (...)
#     132     RuntimeInvalidStateError: If the job was cancelled, and attempting to retrieve result.
#     133 """
#     134 _decoder = decoder or self._final_result_decoder
# --> 135 self.wait_for_final_state(timeout=timeout)
#     136 if self._status == "ERROR":
#     137     error_message = self._reason if self._reason else self._error_message
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/runtime_job_v2.py:255, in RuntimeJobV2.wait_for_final_state(self, timeout)
#     253     self._ws_client_future = self._executor.submit(self._start_websocket_client)
#     254 if self._is_streaming():
# --> 255     self._ws_client_future.result(timeout)
#     256 # poll for status after stream has closed until status is final
#     257 # because status doesn't become final as soon as stream closes
#     258 status = self.status()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
cost_history_dict
plt.plot(cost_history_dict['cost_history'])

# %%
cost_history_dict
plt.plot(cost_history_dict['cost_history'])

# %%
# !pip install nftopt
# Out:
# Collecting nftopt
#   Downloading nftopt-0.0.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from nftopt) (1.26.4)
# Requirement already satisfied: scipy in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from nftopt) (1.13.1)
# Downloading nftopt-0.0.1-py3-none-any.whl (6.9 kB)
# Installing collected packages: nftopt
# Successfully installed nftopt-0.0.1

# %% [markdown]
# ## Step 4: Post-process, return result in classical format.

# %%
all(cost_history_dict["prev_vector"] == res.x)

# %%
cost_history_dict["iters"] == res.nfev

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %%
cost_history_dict
# Out:
# {'prev_vector': array([3.05888996, 4.43727613, 5.39903657, 5.66676143, 3.91592233,
#         4.00972591, 4.42010001, 2.20419641, 1.54907842, 4.74382172,
#         1.6739801 , 4.65247405, 5.86036756, 4.70397595, 0.87260049,
#         1.27107314]),
#  'iters': 20,
#  'cost_history': [0.14922586116758643,
#   -0.11612803571621408,
#   0.07002776280206445,
#   -0.13386988850633055,
#   -0.3302387656462088,
#   -0.10234731983003965,
#   -0.13772207900026967,
#   -0.45905039527309566,
#   -0.445916509386791,
#   -0.36337138067990404,
#   -0.42997434693744946,
#   -0.28915363465327376,
#   -0.35322293062687277,
#   -0.5704129149833769,
#   -0.47988316089181043,
#   -0.46759465876835415,
#   -0.24320415638696258,
#   -0.588662767522721,
#   -0.44708847005466235,
#   -0.5228542313152235]}

# %%
plt.plot(cost_history_dict['cost_history'])
