# %% [markdown]
# ### Import

# %%
# imports
import numpy as np
from typing import List, Callable
from scipy.optimize import minimize
from scipy.optimize._optimize import OptimizeResult
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector, Operator, SparsePauliOp
from qiskit.primitives import StatevectorSampler, PrimitiveJob
from qiskit.circuit.library import TwoLocal
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.visualization import plot_histogram
from qiskit_ibm_runtime.fake_provider import FakeOsaka
from qiskit_ibm_runtime import Session, EstimatorV2 as Estimator
from qiskit_aer import AerSimulator
from nftopt import nakanishi_fujii_todo

# %% [markdown]
# ### Hamiltonian

# %%
hamiltonian = SparsePauliOp.from_list(
                [("IIII", -0.0996), 
                ("IIIZ", 0.1711), 
                ("IIZI", 0.1711), 
                ("IZII", -0.2225), 
                ("ZIII", -0.2225), 
                ("IIZZ", 0.1686), 
                ("IZIZ", 0.1205), 
                ("ZIIZ", 0.1658), 
                ("IZZI", 0.1658), 
                ("ZIZI", 0.1205), 
                ("ZZII", 0.1743), 
                ("XYYX", 0.0453), 
                ("YXXY", 0.0453), 
                ("YYXX", -0.0453), 
                ("XXYY", -0.0453)]
            )
# print(hamiltonian.to_matrix())

# %% [markdown]
# ### Ansatz

# %%
num_qubits = 4

entangler_map = [[0, 1], [1, 2], [2,3], [3,0]]  # entangle the first and last two-way
ansatz = TwoLocal(num_qubits, 'ry', 'cx', entangler_map, reps=1, skip_final_rotation_layer=True)

ansatz.decompose().draw('mpl')

# %% [markdown]
# ### Transpile

# %%
num_params = ansatz.num_parameters
num_params
# Out:
# 4

# %%
backend_answer = FakeOsaka()
optimization_level_answer = 2
pm = generate_preset_pass_manager(backend=backend_answer,optimization_level=optimization_level_answer)
isa_circuit = pm.run(ansatz)
isa_circuit.draw('mpl', idle_wires=False,)

# %%
# Define our Hamiltonian
hamiltonian_isa = hamiltonian.apply_layout(layout=isa_circuit.layout)

# %% [markdown]
# ### Cost Function

# %%
def cost_func(params, ansatz, hamiltonian, estimator, callback_dict):
    """Return estimate of energy from estimator

    Parameters:
        params (ndarray): Array of ansatz parameters
        ansatz (QuantumCircuit): Parameterized ansatz circuit
        hamiltonian (SparsePauliOp): Operator representation of Hamiltonian
        estimator (EstimatorV2): Estimator primitive instance

    Returns:
        float: Energy estimate
    """
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    callback_dict["iters"] += 1
    callback_dict["prev_vector"] = params
    callback_dict["cost_history"].append(energy)

    print(energy)
    return energy, result

# %%
callback_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

x0 = 2 * np.pi * np.random.random(num_params)
x0
# Out:
# array([6.01053846, 5.2824754 , 5.77197572, 2.47090891])

# %% [markdown]
# ### Run using FakeOsaka Backend

# %%
backend = FakeOsaka()
# backend = AerSimulator()

# Here we have updated the cost function to return only the energy to be compatible with recent scipy versions (>=1.10)
def cost_func_2(*args, **kwargs):
    energy, result = cost_func(*args, **kwargs)
    return energy

with Session(backend=backend) as session:
    estimator = Estimator(session=session)

    res = minimize(
        cost_func_2,
        x0,
        args=(isa_circuit, hamiltonian_isa, estimator, callback_dict),
        method=nakanishi_fujii_todo,
        options={'maxiter': 30})
# Out:
# /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/session.py:157: UserWarning: Session is not supported in local testing mode or when using a simulator.
#   warnings.warn(
# -0.08636318359375002
# -0.14102016601562498
# -0.17419531249999998
# -0.291365478515625
# 0.06404042968749998
# -0.3824439453125
# -0.51464912109375
# -0.621681640625
# -0.9386435546874999
# -0.39564423828125
# -0.33855878906250003
# -0.182201171875
# -0.44903066406250003
# -0.34973081054687494
# -0.37989506835937514
# -0.7865154296875001
# -0.7925926269531252
# -0.34839873046875003
# -0.3478748535156249
# -0.3105677734375
# -0.32848110351562504
# -0.40617651367187496
# -0.35039238281249996
# -0.7848951660156251
# -0.78401728515625
# -0.388587255859375
# -0.38325932617187497
# -0.31993261718749993
# -0.312500830078125
# -0.36612734375000006
# -0.37241875
# -0.7821849609375
# -0.7926326171875001
# -0.36349184570312504
# -0.355333984375
# -0.33166201171875
# -0.30092851562499995
# -0.37331489257812495
# -0.3617609863281249
# -0.7921487792968751
# -0.7875664550781251
# -0.33338725585937495
# -0.36838427734375007
# -0.31572680664062514
# -0.33031284179687503
# -0.3742831054687498
# -0.3707257812500001
# -0.7958306152343751
# -0.7860378417968751
# -0.39479506835937483
# -0.360951953125
# -0.30256738281250006
# -0.307519140625
# -0.3656515625
# -0.3672994628906251
# -0.781084912109375
# -0.7896583496093749
# -0.79831669921875
# -1.047975830078125
# -0.37034013671874993
# -0.36026879882812496
# -0.31376176757812513
# -0.305300830078125
# -0.3538423828124999
# -0.35830883789062495
# -0.7875545410156248
# -0.795487451171875
# -0.37255175781249994
# -0.36149355468750005
# -0.29877861328125005
# -0.32419169921874996
# -0.3855812011718748
# -0.37410068359375004
# -0.7955269531250001
# -0.7928251464843751
# -0.368767822265625
# -0.348543359375
# -0.33825932617187504
# -0.30785947265625
# -0.36680458984375014
# -0.3695848632812499
# -0.783016552734375
# -0.7870570800781248
# -0.36977895507812497
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 12
#       9 with Session(backend=backend) as session:
#      10     estimator = Estimator(session=session)
# ---> 12     res = minimize(
#      13         cost_func_2,
#      14         x0,
#      15         args=(isa_circuit, hamiltonian_isa, estimator, callback_dict),
#      16         method=nakanishi_fujii_todo,
#      17         options={'maxiter': 30})
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_minimize.py:636, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     630         options.setdefault('barrier_tol', tol)
#     632 if meth == '_custom':
#     633     # custom method called before bounds and constraints are 'standardised'
#     634     # custom method should be able to accept whatever bounds/constraints
#     635     # are provided to it.
# --> 636     return method(fun, x0, args=args, jac=jac, hess=hess, hessp=hessp,
#     637                   bounds=bounds, constraints=constraints,
#     638                   callback=callback, **options)
#     640 constraints = standardize_constraints(constraints, x0, meth)
#     642 remove_vars = False
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/nftopt/nft.py:85, in nakanishi_fujii_todo(fun, x0, args, maxfev, reset_interval, eps, callback, **_)
#      83 p = np.copy(x0)
#      84 p[idx] = x0[idx] - np.pi / 2
# ---> 85 z3 = fun(p, *args)
#      86 funcalls += 1
#      88 z2 = z1 + z3 - z0
#
# Cell In[18], line 6, in cost_func_2(*args, **kwargs)
#       5 def cost_func_2(*args, **kwargs):
# ----> 6     energy, result = cost_func(*args, **kwargs)
#       7     return energy
#
# Cell In[13], line 14, in cost_func(params, ansatz, hamiltonian, estimator, callback_dict)
#       2 """Return estimate of energy from estimator
#       3
#       4 Parameters:
#    (...)
#      11     float: Energy estimate
#      12 """
#      13 pub = (ansatz, [hamiltonian], [params])
# ---> 14 result = estimator.run(pubs=[pub]).result()
#      15 energy = result[0].data.evs[0]
#      17 callback_dict["iters"] += 1
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/primitives/primitive_job.py:51, in PrimitiveJob.result(self)
#      49 def result(self) -> ResultT:
#      50     self._check_submitted()
# ---> 51     return self._future.result()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
print(callback_dict['cost_history'])
# Out:
# [-0.08636318359375002, -0.14102016601562498, -0.17419531249999998, -0.291365478515625, 0.06404042968749998, -0.3824439453125, -0.51464912109375, -0.621681640625, -0.9386435546874999, -0.39564423828125, -0.33855878906250003, -0.182201171875, -0.44903066406250003, -0.34973081054687494, -0.37989506835937514, -0.7865154296875001, -0.7925926269531252, -0.34839873046875003, -0.3478748535156249, -0.3105677734375, -0.32848110351562504, -0.40617651367187496, -0.35039238281249996, -0.7848951660156251, -0.78401728515625, -0.388587255859375, -0.38325932617187497, -0.31993261718749993, -0.312500830078125, -0.36612734375000006, -0.37241875, -0.7821849609375, -0.7926326171875001, -0.36349184570312504, -0.355333984375, -0.33166201171875, -0.30092851562499995, -0.37331489257812495, -0.3617609863281249, -0.7921487792968751, -0.7875664550781251, -0.33338725585937495, -0.36838427734375007, -0.31572680664062514, -0.33031284179687503, -0.3742831054687498, -0.3707257812500001, -0.7958306152343751,

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 20
#      17 estimator = Estimator(session=session)
#      18 # estimator.options.default_shots = 10000
# ---> 20 res = minimize(
#      21     cost_func_2,
#      22     x0,
#      23     args=(isa_circuit, hamiltonian_isa, estimator, callback_dict),
#      24     method=nakanishi_fujii_todo,
#      25     options={'maxiter': 30})
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_minimize.py:636, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     630         options.setdefault('barrier_tol', tol)
#     632 if meth == '_custom':
#     633     # custom method called before bounds and constraints are 'standardised'
#     634     # custom method should be able to accept whatever bounds/constraints
#     635     # are provided to it.
# --> 636     return method(fun, x0, args=args, jac=jac, hess=hess, hessp=hessp,
#     637                   bounds=bounds, constraints=constraints,
#     638                   callback=callback, **options)
#     640 constraints = standardize_constraints(constraints, x0, meth)
#     642 remove_vars = False
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/nftopt/nft.py:80, in nakanishi_fujii_todo(fun, x0, args, maxfev, reset_interval, eps, callback, **_)
#      78 p = np.copy(x0)
#      79 p[idx] = x0[idx] + np.pi / 2
# ---> 80 z1 = fun(p, *args)
#      81 funcalls += 1
#      83 p = np.copy(x0)
#
# Cell In[25], line 13, in cost_func_2(*args, **kwargs)
#      12 def cost_func_2(*args, **kwargs):
# ---> 13     energy, result = cost_func(*args, **kwargs)
#      14     return energy
#
# Cell In[13], line 14, in cost_func(params, ansatz, hamiltonian, estimator, callback_dict)
#       2 """Return estimate of energy from estimator
#       3
#       4 Parameters:
#    (...)
#      11     float: Energy estimate
#      12 """
#      13 pub = (ansatz, [hamiltonian], [params])
# ---> 14 result = estimator.run(pubs=[pub]).result()
#      15 energy = result[0].data.evs[0]
#      17 callback_dict["iters"] += 1
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/primitives/primitive_job.py:51, in PrimitiveJob.result(self)
#      49 def result(self) -> ResultT:
#      50     self._check_submitted()
# ---> 51     return self._future.result()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
callback_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}


backend = FakeOsaka()
# backend = AerSimulator()

# Here we have updated the cost function to return only the energy to be compatible with recent scipy versions (>=1.10)
def cost_func_2(*args, **kwargs):
    energy, result = cost_func(*args, **kwargs)
    return energy

with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    # estimator.options.default_shots = 10000

    res = minimize(
        cost_func_2,
        x0,
        args=(isa_circuit, hamiltonian_isa, estimator, callback_dict),
        method='cobyla',
        options={'maxiter': 30})
# Out:
# /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/session.py:157: UserWarning: Session is not supported in local testing mode or when using a simulator.
#   warnings.warn(
# -1.0505209960937498
# -0.7204852050781251
# -0.698212939453125
# -0.7416525878906249
# -0.9348588378906252
# -0.74770732421875
# -0.9574851074218751
# -1.0355287597656249
# -1.036212939453125
# -1.024960986328125
# -1.0438410156250002
# -1.0338709472656253
# -1.0427978027343747
# -1.0456552734374998
# -1.045767431640625
# -1.0407697265625
# -1.045271240234375
# -1.039811572265625
# -1.0421509277343748
# -1.0528279296875
# -1.04982001953125
# -1.0441080566406253
# -1.043762255859375
# -1.04614638671875
# -1.0450958984374998
# -1.050848388671875
# -1.0443399902343748
# -1.0439458007812499
# -1.0409717285156248
# -1.0473412109375

# %%
-1.0505209960937498
-0.7204852050781251
-0.698212939453125
-0.7416525878906249
-0.9348588378906252
-0.74770732421875
-0.9574851074218751
-1.0355287597656249
-1.036212939453125
-1.024960986328125
-1.0438410156250002
-1.0338709472656253
-1.0427978027343747
-1.0456552734374998
-1.045767431640625
-1.0407697265625
-1.045271240234375
-1.039811572265625
-1.0421509277343748
-1.0528279296875
-1.04982001953125
-1.0441080566406253
-1.043762255859375
-1.04614638671875
-1.0450958984374998
-1.050848388671875
-1.0443399902343748
-1.0439458007812499
-1.0409717285156248
-1.0473412109375

# %%
plt.plot(callback_dict['cost_history'])
