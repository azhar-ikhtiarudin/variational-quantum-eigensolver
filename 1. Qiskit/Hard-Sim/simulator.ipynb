# %% [markdown]
# ### Import

# %%
# imports
import numpy as np
from typing import List, Callable
from scipy.optimize import minimize
from scipy.optimize._optimize import OptimizeResult
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector, Operator, SparsePauliOp
from qiskit.primitives import StatevectorSampler, PrimitiveJob
from qiskit.circuit.library import TwoLocal
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.visualization import plot_histogram
from qiskit_ibm_runtime.fake_provider import FakeOsaka
from qiskit_ibm_runtime import Session, EstimatorV2 as Estimator
from qiskit_aer import AerSimulator
from nftopt import nakanishi_fujii_todo

# %%
hamiltonian = SparsePauliOp.from_list(
                [("IIII", -0.0996), 
                ("IIIZ", 0.1711), 
                ("IIZI", 0.1711), 
                ("IZII", -0.2225), 
                ("ZIII", -0.2225), 
                ("IIZZ", 0.1686), 
                ("IZIZ", 0.1205), 
                ("ZIIZ", 0.1658), 
                ("IZZI", 0.1658), 
                ("ZIZI", 0.1205), 
                ("ZZII", 0.1743), 
                ("XYYX", 0.0453), 
                ("YXXY", 0.0453), 
                ("YYXX", -0.0453), 
                ("XXYY", -0.0453)]
            )

# hamiltonian = SparsePauliOp.from_list(
#     [("IIII", -0.81054), 
#      ("IZIZ", 0.16614), 
#      ("ZIZI", 0.16892), 
#      ("ZIII", 0.17218), 
#      ("IIZI", 0.17218), 
#      ("IZII", -0.22573), 
#      ("IIIZ", -0.22573), 
#      ("ZZII", 0.12091), 
#      ("IIZZ", 0.12091), 
#      ("ZIIZ", 0.166145), 
#      ("IZZI", 0.166145), 
#      ("YYYY", 0.04523), 
#      ("XXYY", 0.04523), 
#      ("YYXX", 0.04523), 
#      ("XXXX", 0.04523)]
# )
# print(hamiltonian.to_matrix())

# %%
num_qubits = 4

entangler_map = [[0, 1], [1, 2], [2,3], [3,0]]  # entangle the first and last two-way
ansatz = TwoLocal(num_qubits, 'ry', 'cx', entangler_map, reps=1, skip_final_rotation_layer=True)

ansatz.decompose().draw('mpl')

# %%
num_params = ansatz.num_parameters
num_params
# Out:
# 4

# %%
backend_answer = FakeOsaka()
optimization_level_answer = 2
pm = generate_preset_pass_manager(backend=backend_answer,optimization_level=optimization_level_answer)
isa_circuit = pm.run(ansatz)
isa_circuit.draw('mpl', idle_wires=False,)

# %%
# Define our Hamiltonian
hamiltonian_isa = hamiltonian.apply_layout(layout=isa_circuit.layout)
hamiltonian_isa
# Out:
# SparsePauliOp(['IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIZIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIZZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIZZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIYXXIIIIIIIIYIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIXYYIIIIIIIIXIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIYYXIIIIIIIIXIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIXXYIIIIIIIIYIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII'],
#               coeffs=[-0.0996+0.j,  0.1711+0.j,  0.1711+0.j, -0.2225+0.j, -0.2225+0.j,
#   0.1686+0.j,  0.1205+0.j,  0.1658+0.j,  0.1658+0.j,  0.1205+0.j,
#   0.1743+0.j,  0.0453+0.j,  0.0453+0.j, -0.0453+0.j, -0.0453+0.j])

# %%
def cost_func(params, ansatz, hamiltonian, estimator, callback_dict):
    """Return estimate of energy from estimator

    Parameters:
        params (ndarray): Array of ansatz parameters
        ansatz (QuantumCircuit): Parameterized ansatz circuit
        hamiltonian (SparsePauliOp): Operator representation of Hamiltonian
        estimator (EstimatorV2): Estimator primitive instance

    Returns:
        float: Energy estimate
    """
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    callback_dict["iters"] += 1
    callback_dict["prev_vector"] = params
    callback_dict["cost_history"].append(energy)

    print(f"Iters. done: {callback_dict['iters']} [Current cost: {energy}]")
    return energy, result

# %%
callback_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

x0 = 2 * np.pi * np.random.random(num_params)
x0
# Out:
# array([0.42859038, 2.6060971 , 6.20144282, 5.33988517])

# %%
# backend = FakeOsaka()
backend = AerSimulator()

# Here we have updated the cost function to return only the energy to be compatible with recent scipy versions (>=1.10)
def cost_func_2(*args, **kwargs):
    energy, result = cost_func(*args, **kwargs)
    return energy

with Session(backend=backend) as session:
    estimator = Estimator(session=session)

    res = minimize(
        cost_func_2,
        x0,
        args=(isa_circuit, hamiltonian_isa, estimator, callback_dict),
        method='cobyla',
        options={'maxiter': 30})
# Out:
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/process.py", line 263, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/process.py", line 212, in _process_chunk
#     return [fn(*args) for args in chunk]
#             ^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/utils/parallel.py", line 101, in _task_wrapper
#     return task(value, *task_args, **task_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/passmanager/passmanager.py", line 330, in _run_workflow_in_new_process
#     return _run_workflow(
#            ^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/passmanager/passmanager.py", line 292, in _run_workflow
#     passmanager_ir, final_state = flow_controller.execute(
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/passmanager/base_tasks.py", line 218, in execute
#     passmanager_ir, state = next_task.execute(
#                             ^^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/transpiler/basepasses.py", line 195, in execute
#     new_dag, state = super().execute(
#                      ^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/passmanager/base_tasks.py", line 98, in execute
#     ret = self.run(passmanager_ir)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/transpiler/passes/utils/control_flow.py", line 59, in out
#     return method(self, dag)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/transpiler/passes/optimization/optimize_1q_decomposition.py", line 206, in run
#     best_circuit_sequence = self._resynthesize_run(operator, qubit)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/transpiler/passes/optimization/optimize_1q_decomposition.py", line 131, in _resynthesize_run
#     available_1q_basis = set(self._target.operation_names_for_qargs(qubits_tuple))
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/transpiler/target.py", line 703, in operation_names_for_qargs
#     raise KeyError(f"{qargs} not in target.")
# KeyError: '(103,) not in target.'
# """
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 12
#       9 with Session(backend=backend) as session:
#      10     estimator = Estimator(session=session)
# ---> 12     res = minimize(
#      13         cost_func_2,
#      14         x0,
#      15         args=(isa_circuit, hamiltonian_isa, estimator, callback_dict),
#      16         method='cobyla',
#      17         options={'maxiter': 30})
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_minimize.py:719, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     716     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     717                         **options)
#     718 elif meth == 'cobyla':
# --> 719     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     720                            bounds=bounds, **options)
#     721 elif meth == 'slsqp':
#     722     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     723                           constraints, callback=callback, **options)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:278, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     275 def _jac(x, *args):
#     276     return None
# --> 278 sf = _prepare_scalar_function(fun, x0, args=args, jac=_jac)
#     280 def calcfc(x, con):
#     281     f = sf.fun(x)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_optimize.py:288, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     284     bounds = (-np.inf, np.inf)
#     286 # ScalarFunction caches. Reuse of fun(x) during grad
#     287 # calculation reduces overall function evaluations.
# --> 288 sf = ScalarFunction(fun, x0, args, grad, hess,
#     289                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     291 return sf
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:166, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     163     self.f = fun_wrapped(self.x)
#     165 self._update_fun_impl = update_fun
# --> 166 self._update_fun()
#     168 # Gradient evaluation
#     169 if callable(grad):
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# Cell In[11], line 6, in cost_func_2(*args, **kwargs)
#       5 def cost_func_2(*args, **kwargs):
# ----> 6     energy, result = cost_func(*args, **kwargs)
#       7     return energy
#
# Cell In[7], line 14, in cost_func(params, ansatz, hamiltonian, estimator, callback_dict)
#       2 """Return estimate of energy from estimator
#       3
#       4 Parameters:
#    (...)
#      11     float: Energy estimate
#      12 """
#      13 pub = (ansatz, [hamiltonian], [params])
# ---> 14 result = estimator.run(pubs=[pub]).result()
#      15 energy = result[0].data.evs[0]
#      17 callback_dict["iters"] += 1
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/primitives/primitive_job.py:51, in PrimitiveJob.result(self)
#      49 def result(self) -> ResultT:
#      50     self._check_submitted()
# ---> 51     return self._future.result()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit/primitives/backend_estimator_v2.py:151, in BackendEstimatorV2._run(self, pubs)
#     150 def _run(self, pubs: list[EstimatorPub]) -> PrimitiveResult[PubResult]:
# --> 151     return PrimitiveResult([self._run_pub(pub) for pub in pubs])
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit/primitives/backend_estimator_v2.py:169, in BackendEstimatorV2._run_pub(self, pub)
#     167     param_index = bc_param_ind[index]
#     168     param_obs_map[param_index].update(bc_obs[index].keys())
# --> 169 expval_map = self._calc_expval_paulis(circuit, parameter_values, param_obs_map, shots)
#     171 # calculate expectation values (evs) and standard errors (stds)
#     172 evs = np.zeros_like(bc_param_ind, dtype=float)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit/primitives/backend_estimator_v2.py:198, in BackendEstimatorV2._calc_expval_paulis(self, circuit, parameter_values, param_obs_map, shots)
#     196     # sort pauli_strings so that the order is deterministic
#     197     meas_paulis = PauliList(sorted(pauli_strings))
# --> 198     new_circuits = self._preprocessing(bound_circuit, meas_paulis, param_index)
#     199     circuits.extend(new_circuits)
#     201 # run circuits
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit/primitives/backend_estimator_v2.py:255, in BackendEstimatorV2._preprocessing(self, circuit, observable, param_index)
#     252         meas_circuits.append(meas_circuit)
#     254 # unroll basis gates
# --> 255 meas_circuits = self._passmanager.run(meas_circuits)
#     257 # combine measurement circuits
#     258 preprocessed_circuits = []
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/transpiler/passmanager.py:420, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     417 @wraps(meth)
#     418 def wrapper(*meth_args, **meth_kwargs):
#     419     try:
# --> 420         return meth(*meth_args, **meth_kwargs)
#     421     except PassManagerError as ex:
#     422         raise TranspilerError(ex.message) from ex
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/transpiler/passmanager.py:182, in PassManager.run(self, circuits, output_name, callback, num_processes)
#     179 if callback is not None:
#     180     callback = _legacy_style_callback(callback)
# --> 182 return super().run(
#     183     in_programs=circuits,
#     184     callback=callback,
#     185     output_name=output_name,
#     186     num_processes=num_processes,
#     187 )
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/passmanager/passmanager.py:246, in BasePassManager.run(***failed resolving arguments***)
#     240 del kwargs
#     242 # Pass manager may contain callable and we need to serialize through dill rather than pickle.
#     243 # See https://github.com/Qiskit/qiskit-terra/pull/3290
#     244 # Note that serialized object is deserialized as a different object.
#     245 # Thus, we can resue the same manager without state collision, without building it per thread.
# --> 246 return parallel_map(
#     247     _run_workflow_in_new_process,
#     248     values=in_programs,
#     249     task_kwargs={"pass_manager_bin": dill.dumps(self)},
#     250     num_processes=num_processes,
#     251 )
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/utils/parallel.py:171, in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     169     # Otherwise just reset parallel flag and error
#     170     os.environ["QISKIT_IN_PARALLEL"] = "FALSE"
# --> 171     raise error
#     173 os.environ["QISKIT_IN_PARALLEL"] = "FALSE"
#     174 return results
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/utils/parallel.py:163, in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     160         param = ((task, value, task_args, task_kwargs) for value in values)
#     161         future = executor.map(_task_wrapper, param)
# --> 163     results = list(future)
#     165 except (KeyboardInterrupt, Exception) as error:
#     166     if isinstance(error, KeyboardInterrupt):
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/process.py:642, in _chain_from_iterable_of_lists(iterable)
#     636 def _chain_from_iterable_of_lists(iterable):
#     637     """
#     638     Specialized implementation of itertools.chain.from_iterable.
#     639     Each item in *iterable* should be a list.  This function is
#     640     careful not to keep references to yielded objects.
#     641     """
# --> 642     for element in iterable:
#     643         element.reverse()
#     644         while element:
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# KeyError: '(103,) not in target.'

# %% [markdown]
# ### NFT Optimizer

# %%
# backend = FakeOsaka()
backend = AerSimulator()

# Here we have updated the cost function to return only the energy to be compatible with recent scipy versions (>=1.10)
def cost_func_2(*args, **kwargs):
    energy, result = cost_func(*args, **kwargs)
    return energy

with Session(backend=backend) as session:
    estimator = Estimator(session=session)

    res = minimize(
        cost_func_2,
        x0,
        args=(isa_circuit, hamiltonian_isa, estimator, callback_dict),
        method=nakanishi_fujii_todo,
        options={'maxiter': 30})
# Out:
# -0.9344823754882812
# -0.49124780273437496
# -1.4994309887695314
# -0.7256880761718753
# -1.4811255810546875
# -0.9995012744140624
# -1.2670102612304683
# -1.2589482373046876
# -1.8408137866210934
# -1.184166940917969
# -1.1554865502929692
# -1.0464969287109374
# -1.0448009667968752
# -1.1218419409179687
# -1.1158672607421871
# -1.5458713818359378
# -1.5431250488281254
# -1.1784244653320315
# -1.155640458984375
# -1.0365614794921876
# -1.0760775048828128
# -1.1068922241210937
# -1.1460502221679687
# -1.5384490795898436
# -1.5399158422851562
# -1.1612327270507814
# -1.1730129467773438
# -1.0453092016601562
# -1.052876784667969
# -1.123300859375
# -1.105276169433594
# -1.5487541064453125
# -1.5503680322265625
# -1.1644681567382809
# -1.1786881665039062
# -1.0796417431640626
# -1.0456175537109376
# -1.1252601171875
# -1.1123717749023436
# -1.5554254736328126
# -1.5473919042968751
# -1.1636413061523438
# -1.1569277221679688
# -1.0464938134765625
# -1.0758082910156253
# -1.1136508593749999
# -1.1218388452148433
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 12
#       9 with Session(backend=backend) as session:
#      10     estimator = Estimator(session=session)
# ---> 12     res = minimize(
#      13         cost_func_2,
#      14         x0,
#      15         args=(isa_circuit, hamiltonian_isa, estimator, callback_dict),
#      16         method=nakanishi_fujii_todo,
#      17         options={'maxiter': 30})
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_minimize.py:636, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     630         options.setdefault('barrier_tol', tol)
#     632 if meth == '_custom':
#     633     # custom method called before bounds and constraints are 'standardised'
#     634     # custom method should be able to accept whatever bounds/constraints
#     635     # are provided to it.
# --> 636     return method(fun, x0, args=args, jac=jac, hess=hess, hessp=hessp,
#     637                   bounds=bounds, constraints=constraints,
#     638                   callback=callback, **options)
#     640 constraints = standardize_constraints(constraints, x0, meth)
#     642 remove_vars = False
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/nftopt/nft.py:80, in nakanishi_fujii_todo(fun, x0, args, maxfev, reset_interval, eps, callback, **_)
#      78 p = np.copy(x0)
#      79 p[idx] = x0[idx] + np.pi / 2
# ---> 80 z1 = fun(p, *args)
#      81 funcalls += 1
#      83 p = np.copy(x0)
#
# Cell In[25], line 6, in cost_func_2(*args, **kwargs)
#       5 def cost_func_2(*args, **kwargs):
# ----> 6     energy, result = cost_func(*args, **kwargs)
#       7     return energy
#
# Cell In[17], line 14, in cost_func(params, ansatz, hamiltonian, estimator, callback_dict)
#       2 """Return estimate of energy from estimator
#       3
#       4 Parameters:
#    (...)
#      11     float: Energy estimate
#      12 """
#      13 pub = (ansatz, [hamiltonian], [params])
# ---> 14 result = estimator.run(pubs=[pub]).result()
#      15 energy = result[0].data.evs[0]
#      17 callback_dict["iters"] += 1
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/estimator.py:151, in EstimatorV2.run(self, pubs, precision)
#     137 """Submit a request to the estimator primitive.
#     138
#     139 Args:
#    (...)
#     148
#     149 """
#     150 coerced_pubs = [EstimatorPub.coerce(pub, precision) for pub in pubs]
# --> 151 return self._run(coerced_pubs)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/base_primitive.py:154, in BasePrimitiveV2._run(self, pubs)
#     152 if self._backend:
#     153     for pub in pubs:
# --> 154         if getattr(self._backend, "target", None) and not is_simulator(self._backend):
#     155             validate_isa_circuits([pub.circuit], self._backend.target)
#     157         if isinstance(self._backend, IBMBackend):
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_aer/backends/aerbackend.py:348, in AerBackend.target(self)
#     345 if self._target is not None:
#     346     return self._target
# --> 348 tgt = convert_to_target(self.configuration(), self.properties(), None, NAME_MAPPING)
#     349 if self._coupling_map is not None:
#     350     tgt._coupling_graph = self._coupling_map.graph.copy()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/providers/backend_compat.py:74, in convert_to_target(configuration, properties, defaults, custom_name_mapping, add_delay, filter_faulty)
#      71 required = ["measure", "delay"]
#      73 # Load Qiskit object representation
# ---> 74 qiskit_inst_mapping = get_standard_gate_name_mapping()
#      75 if custom_name_mapping:
#      76     qiskit_inst_mapping.update(custom_name_mapping)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/circuit/library/standard_gates/__init__.py:115, in get_standard_gate_name_mapping()
#      57 # Standard gates library mapping, multicontrolled gates not included since they're
#      58 # variable width
#      59 gates = [
#      60     IGate(),
#      61     SXGate(),
#    (...)
#     113     Measure(),
#     114 ]
# --> 115 name_mapping = {gate.name: gate for gate in gates}
#     116 return name_mapping
#
# KeyboardInterrupt:

# %%
plt.plot(callback_dict['cost_history'])

# %% [markdown]
# ### COBYLA Optimizer

# %%
callback_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}


# backend = FakeOsaka()
backend = AerSimulator()

# Here we have updated the cost function to return only the energy to be compatible with recent scipy versions (>=1.10)
def cost_func_2(*args, **kwargs):
    energy, result = cost_func(*args, **kwargs)
    return energy

with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    # estimator.options.default_shots = 10000

    res = minimize(
        cost_func_2,
        x0,
        args=(isa_circuit, hamiltonian_isa, estimator, callback_dict),
        method='cobyla',
        options={'maxiter': 30})
# Out:
# Iters. done: 1 [Current cost: -0.5339847656250001]
# Iters. done: 2 [Current cost: -0.368340283203125]
# Iters. done: 3 [Current cost: -0.533520263671875]
# Iters. done: 4 [Current cost: -0.5149858886718751]
# Iters. done: 5 [Current cost: -0.6833519042968751]
# Iters. done: 6 [Current cost: -0.723322900390625]
# Iters. done: 7 [Current cost: -1.050956689453125]
# Iters. done: 8 [Current cost: -1.068693603515625]
# Iters. done: 9 [Current cost: -0.9150162109375002]
# Iters. done: 10 [Current cost: -0.923300341796875]
# Iters. done: 11 [Current cost: -1.0511765624999998]
# Iters. done: 12 [Current cost: -0.74929052734375]
# Iters. done: 13 [Current cost: -0.9165070800781248]
# Iters. done: 14 [Current cost: -1.0398024902343754]
# Iters. done: 15 [Current cost: -1.0346369140625]
# Iters. done: 16 [Current cost: -1.111166015625]
# Iters. done: 17 [Current cost: -1.1231132324218753]
# Iters. done: 18 [Current cost: -1.1190150878906249]
# Iters. done: 19 [Current cost: -1.1278097656249997]
# Iters. done: 20 [Current cost: -1.0882027343750003]
# Iters. done: 21 [Current cost: -1.1278984863281247]
# Iters. done: 22 [Current cost: -1.125452783203125]
# Iters. done: 23 [Current cost: -1.1200541503906247]
# Iters. done: 24 [Current cost: -1.1285398925781251]
# Iters. done: 25 [Current cost: -1.1298976562499998]
# Iters. done: 26 [Current cost: -1.120203662109375]
# Iters. done: 27 [Current cost: -1.128834716796875]
# Iters. done: 28 [Current cost: -1.1201593749999998]
# Iters. done: 29 [Current cost: -1.118248681640625]
# Iters. done: 30 [Current cost: -1.117166552734375]

# %%
plt.plot(callback_dict['cost_history'])

# %% [markdown]
# ### Nelder-Mead Optimizer

# %%
callback_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}


# backend = FakeOsaka()
backend = AerSimulator()

# Here we have updated the cost function to return only the energy to be compatible with recent scipy versions (>=1.10)
def cost_func_2(*args, **kwargs):
    energy, result = cost_func(*args, **kwargs)
    return energy

with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    # estimator.options.default_shots = 10000

    res = minimize(
        cost_func_2,
        x0,
        args=(isa_circuit, hamiltonian_isa, estimator, callback_dict),
        method='nelder-mead',
        options={'maxiter': 30})
# Out:
# Iters. done: 1 [Current cost: -0.533906005859375]
# Iters. done: 2 [Current cost: -0.4941262207031249]
# Iters. done: 3 [Current cost: -0.5310747558593749]
# Iters. done: 4 [Current cost: -0.5311656250000001]
# Iters. done: 5 [Current cost: -0.5399377441406249]
# Iters. done: 6 [Current cost: -0.495089697265625]
# Iters. done: 7 [Current cost: -0.5264425292968751]
# Iters. done: 8 [Current cost: -0.5232261230468751]
# Iters. done: 9 [Current cost: -0.532717431640625]
# Iters. done: 10 [Current cost: -0.534707275390625]
# Iters. done: 11 [Current cost: -0.536932275390625]
# Iters. done: 12 [Current cost: -0.5352479492187501]
# Iters. done: 13 [Current cost: -0.5483221191406249]
# Iters. done: 14 [Current cost: -0.5619662109375]
# Iters. done: 15 [Current cost: -0.554233740234375]
# Iters. done: 16 [Current cost: -0.5522159667968751]
# Iters. done: 17 [Current cost: -0.575648828125]
# Iters. done: 18 [Current cost: -0.6008347167968751]
# Iters. done: 19 [Current cost: -0.61635947265625]
# Iters. done: 20 [Current cost: -0.680685791015625]
# Iters. done: 21 [Current cost: -0.6414545410156252]
# Iters. done: 22 [Current cost: -0.7250914062499999]
# Iters. done: 23 [Current cost: -0.8476282714843749]
# Iters. done: 24 [Current cost: -0.8580685546875]
# Iters. done: 25 [Current cost: -1.0062492675781247]
# Iters. done: 26 [Current cost: -1.0010119140625]
# Iters. done: 27 [Current cost: -1.0719199218750002]
# Iters. done: 28 [Current cost: -1.023815966796875]
# Iters. done: 29 [Current cost: -1.1107584472656251]
# Iters. done: 30 [Current cost: -0.863290771484375]
# Iters. done: 31 [Current cost: -0.9929893554687499]
# Iters. done: 32 [Current cost: -1.0805670898437496]
# Iters. done: 33 [Current cost: -1.0792908691406247]
# Iters. done: 34 [Current cost: -0.9442288085937501]
# Iters. done: 35 [Current cost: -1.08893505859375]
# Iters. done: 36 [Current cost: -1.0533104980468753]
# Iters. done: 37 [Current cost: -1.0975022460937502]
# Iters. done: 38 [Current cost: -1.0588571289062498]
# Iters. done: 39 [Current cost: -1.0911126953125003]
# Iters. done: 40 [Current cost: -1.125225048828125]
# Iters. done: 41 [Current cost: -1.1309648437500002]
# Iters. done: 42 [Current cost: -1.0984785644531252]
# Iters. done: 43 [Current cost: -1.123171142578125]
# Iters. done: 44 [Current cost: -1.0959250488281247]
# Iters. done: 45 [Current cost: -1.1168626953125003]
# Iters. done: 46 [Current cost: -1.109409228515625]
# Iters. done: 47 [Current cost: -1.1206069335937503]
# Iters. done: 48 [Current cost: -1.0876491699218747]
# Iters. done: 49 [Current cost: -1.1292734375]
# Iters. done: 50 [Current cost: -1.126704052734375]
# Iters. done: 51 [Current cost: -1.1254516113281257]

# %%
plt.plot(callback_dict['cost_history'])

# %%
callback_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}


# backend = FakeOsaka()
backend = AerSimulator()

# Here we have updated the cost function to return only the energy to be compatible with recent scipy versions (>=1.10)
def cost_func_2(*args, **kwargs):
    energy, result = cost_func(*args, **kwargs)
    return energy

with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    # estimator.options.default_shots = 10000

    res = minimize(
        cost_func_2,
        x0,
        args=(isa_circuit, hamiltonian_isa, estimator, callback_dict),
        method='cobyla',
        options={'maxiter': 30})
# Out:
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/process.py", line 263, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/process.py", line 212, in _process_chunk
#     return [fn(*args) for args in chunk]
#             ^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/utils/parallel.py", line 101, in _task_wrapper
#     return task(value, *task_args, **task_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/passmanager/passmanager.py", line 330, in _run_workflow_in_new_process
#     return _run_workflow(
#            ^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/passmanager/passmanager.py", line 292, in _run_workflow
#     passmanager_ir, final_state = flow_controller.execute(
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/passmanager/base_tasks.py", line 218, in execute
#     passmanager_ir, state = next_task.execute(
#                             ^^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/transpiler/basepasses.py", line 195, in execute
#     new_dag, state = super().execute(
#                      ^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/passmanager/base_tasks.py", line 98, in execute
#     ret = self.run(passmanager_ir)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/transpiler/passes/utils/control_flow.py", line 59, in out
#     return method(self, dag)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/transpiler/passes/optimization/optimize_1q_decomposition.py", line 206, in run
#     best_circuit_sequence = self._resynthesize_run(operator, qubit)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/transpiler/passes/optimization/optimize_1q_decomposition.py", line 131, in _resynthesize_run
#     available_1q_basis = set(self._target.operation_names_for_qargs(qubits_tuple))
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/transpiler/target.py", line 703, in operation_names_for_qargs
#     raise KeyError(f"{qargs} not in target.")
# KeyError: '(103,) not in target.'
# """
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 20
#      17 estimator = Estimator(session=session)
#      18 # estimator.options.default_shots = 10000
# ---> 20 res = minimize(
#      21     cost_func_2,
#      22     x0,
#      23     args=(isa_circuit, hamiltonian_isa, estimator, callback_dict),
#      24     method='cobyla',
#      25     options={'maxiter': 30})
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_minimize.py:719, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     716     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     717                         **options)
#     718 elif meth == 'cobyla':
# --> 719     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     720                            bounds=bounds, **options)
#     721 elif meth == 'slsqp':
#     722     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     723                           constraints, callback=callback, **options)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:278, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     275 def _jac(x, *args):
#     276     return None
# --> 278 sf = _prepare_scalar_function(fun, x0, args=args, jac=_jac)
#     280 def calcfc(x, con):
#     281     f = sf.fun(x)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_optimize.py:288, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     284     bounds = (-np.inf, np.inf)
#     286 # ScalarFunction caches. Reuse of fun(x) during grad
#     287 # calculation reduces overall function evaluations.
# --> 288 sf = ScalarFunction(fun, x0, args, grad, hess,
#     289                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     291 return sf
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:166, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     163     self.f = fun_wrapped(self.x)
#     165 self._update_fun_impl = update_fun
# --> 166 self._update_fun()
#     168 # Gradient evaluation
#     169 if callable(grad):
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# Cell In[14], line 13, in cost_func_2(*args, **kwargs)
#      12 def cost_func_2(*args, **kwargs):
# ---> 13     energy, result = cost_func(*args, **kwargs)
#      14     return energy
#
# Cell In[9], line 14, in cost_func(params, ansatz, hamiltonian, estimator, callback_dict)
#       2 """Return estimate of energy from estimator
#       3
#       4 Parameters:
#    (...)
#      11     float: Energy estimate
#      12 """
#      13 pub = (ansatz, [hamiltonian], [params])
# ---> 14 result = estimator.run(pubs=[pub]).result()
#      15 energy = result[0].data.evs[0]
#      17 callback_dict["iters"] += 1
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/primitives/primitive_job.py:51, in PrimitiveJob.result(self)
#      49 def result(self) -> ResultT:
#      50     self._check_submitted()
# ---> 51     return self._future.result()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit/primitives/backend_estimator_v2.py:151, in BackendEstimatorV2._run(self, pubs)
#     150 def _run(self, pubs: list[EstimatorPub]) -> PrimitiveResult[PubResult]:
# --> 151     return PrimitiveResult([self._run_pub(pub) for pub in pubs])
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit/primitives/backend_estimator_v2.py:169, in BackendEstimatorV2._run_pub(self, pub)
#     167     param_index = bc_param_ind[index]
#     168     param_obs_map[param_index].update(bc_obs[index].keys())
# --> 169 expval_map = self._calc_expval_paulis(circuit, parameter_values, param_obs_map, shots)
#     171 # calculate expectation values (evs) and standard errors (stds)
#     172 evs = np.zeros_like(bc_param_ind, dtype=float)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit/primitives/backend_estimator_v2.py:198, in BackendEstimatorV2._calc_expval_paulis(self, circuit, parameter_values, param_obs_map, shots)
#     196     # sort pauli_strings so that the order is deterministic
#     197     meas_paulis = PauliList(sorted(pauli_strings))
# --> 198     new_circuits = self._preprocessing(bound_circuit, meas_paulis, param_index)
#     199     circuits.extend(new_circuits)
#     201 # run circuits
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit/primitives/backend_estimator_v2.py:255, in BackendEstimatorV2._preprocessing(self, circuit, observable, param_index)
#     252         meas_circuits.append(meas_circuit)
#     254 # unroll basis gates
# --> 255 meas_circuits = self._passmanager.run(meas_circuits)
#     257 # combine measurement circuits
#     258 preprocessed_circuits = []
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/transpiler/passmanager.py:420, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     417 @wraps(meth)
#     418 def wrapper(*meth_args, **meth_kwargs):
#     419     try:
# --> 420         return meth(*meth_args, **meth_kwargs)
#     421     except PassManagerError as ex:
#     422         raise TranspilerError(ex.message) from ex
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/transpiler/passmanager.py:182, in PassManager.run(self, circuits, output_name, callback, num_processes)
#     179 if callback is not None:
#     180     callback = _legacy_style_callback(callback)
# --> 182 return super().run(
#     183     in_programs=circuits,
#     184     callback=callback,
#     185     output_name=output_name,
#     186     num_processes=num_processes,
#     187 )
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/passmanager/passmanager.py:246, in BasePassManager.run(***failed resolving arguments***)
#     240 del kwargs
#     242 # Pass manager may contain callable and we need to serialize through dill rather than pickle.
#     243 # See https://github.com/Qiskit/qiskit-terra/pull/3290
#     244 # Note that serialized object is deserialized as a different object.
#     245 # Thus, we can resue the same manager without state collision, without building it per thread.
# --> 246 return parallel_map(
#     247     _run_workflow_in_new_process,
#     248     values=in_programs,
#     249     task_kwargs={"pass_manager_bin": dill.dumps(self)},
#     250     num_processes=num_processes,
#     251 )
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/utils/parallel.py:171, in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     169     # Otherwise just reset parallel flag and error
#     170     os.environ["QISKIT_IN_PARALLEL"] = "FALSE"
# --> 171     raise error
#     173 os.environ["QISKIT_IN_PARALLEL"] = "FALSE"
#     174 return results
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit/utils/parallel.py:163, in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     160         param = ((task, value, task_args, task_kwargs) for value in values)
#     161         future = executor.map(_task_wrapper, param)
# --> 163     results = list(future)
#     165 except (KeyboardInterrupt, Exception) as error:
#     166     if isinstance(error, KeyboardInterrupt):
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/process.py:642, in _chain_from_iterable_of_lists(iterable)
#     636 def _chain_from_iterable_of_lists(iterable):
#     637     """
#     638     Specialized implementation of itertools.chain.from_iterable.
#     639     Each item in *iterable* should be a list.  This function is
#     640     careful not to keep references to yielded objects.
#     641     """
# --> 642     for element in iterable:
#     643         element.reverse()
#     644         while element:
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# KeyError: '(103,) not in target.'

# %%
from qiskit.algorithms.minimum_eigensolvers import VQE  # new import!!!
from qiskit.algorithms.optimizers import SPSA
from qiskit.circuit.library import TwoLocal
from qiskit.quantum_info import SparsePauliOp
from qiskit.primitives import Estimator
from qiskit_aer.primitives import Estimator as AerEstimator
 
ansatz = TwoLocal(2, 'ry', 'cz')
opt = SPSA(maxiter=50)
 
# shot-based simulation
estimator = Estimator(options={"shots": 2048})
vqe = VQE(estimator, ansatz, opt)
 
# another option
aer_estimator = AerEstimator(run_options={"shots": 2048, "seed": 42})
vqe = VQE(aer_estimator, ansatz, opt)
 
hamiltonian = SparsePauliOp.from_list([("XX", 1), ("XY", 1)])
result = vqe.compute_minimum_eigenvalue(hamiltonian)
 
print(result.eigenvalue)
# Out:
# /tmp/ipykernel_79538/3952590743.py:1: DeprecationWarning: ``qiskit.algorithms`` has been migrated to an independent package: https://github.com/qiskit-community/qiskit-algorithms. The ``qiskit.algorithms`` import path is deprecated as of qiskit-terra 0.25.0 and will be removed no earlier than 3 months after the release date. Please run ``pip install qiskit_algorithms`` and use ``import qiskit_algorithms`` instead.
#   from qiskit.algorithms.minimum_eigensolvers import VQE  # new import!!!
# -0.970703125

# %%
from qiskit.algorithms.minimum_eigensolvers import VQE  # new import!!!
from qiskit.algorithms.optimizers import SPSA
from qiskit.circuit.library import TwoLocal
from qiskit.quantum_info import SparsePauliOp
from qiskit.primitives import Estimator
from qiskit_aer.primitives import Estimator as AerEstimator
 
ansatz = TwoLocal(2, 'ry', 'cz')
opt = SPSA(maxiter=50)
 
# shot-based simulation
estimator = Estimator(options={"shots": 2048})
vqe = VQE(estimator, ansatz, opt)
 
# another option
aer_estimator = AerEstimator(run_options={"shots": 2048, "seed": 42})
vqe = VQE(aer_estimator, ansatz, opt)
 
hamiltonian = SparsePauliOp.from_list([("XX", 1), ("XY", 1)])
result = vqe.compute_minimum_eigenvalue(hamiltonian)
 
print(result.eigenvalue)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from qiskit.algorithms.minimum_eigensolvers import VQE  # new import!!!
#       2 from qiskit.algorithms.optimizers import SPSA
#       3 from qiskit.circuit.library import TwoLocal
#
# ModuleNotFoundError: No module named 'qiskit.algorithms'
