# %%
import numpy as np
import matplotlib.pyplot as plt
au_to_kcal_conversion = 627.509474

# %% [markdown]
# ### VQE Classical Optimizer (Active Space 2,2)

# %%
data_3_2_2_Adagrad = np.loadtxt('N2H4_3_2_2_AdagradOptimizer.txt', delimiter=',')
data_3_2_2_Adam = np.loadtxt('N2H4_3_2_2_AdamOptimizer.txt', delimiter=',')
data_3_2_2_GradientDescent = np.loadtxt('N2H4_3_2_2_GradientDescentOptimizer.txt', delimiter=',')
data_3_2_2_Momentum = np.loadtxt('N2H4_3_2_2_MomentumOptimizer.txt', delimiter=',')
data_3_2_2_NesterovMomentum = np.loadtxt('N2H4_3_2_2_NesterovMomentumOptimizer.txt', delimiter=',')
data_3_2_2_QNG = np.loadtxt('N2H4_3_2_2_QNGOptimizer.txt', delimiter=',')
data_3_2_2_RMSProp = np.loadtxt('N2H4_3_2_2_RMSPropOptimizer.txt', delimiter=',')

# %%
plt.plot(data_3_2_2_Adagrad, label='AdagradOptimizer')
# plt.plot(data_3_2_2_Adam, label='AdamOptimizer')
plt.plot(data_3_2_2_GradientDescent, label='GradientDescentOptimizer')
plt.plot(data_3_2_2_Momentum, label='MomentumOptimizer')
plt.plot(data_3_2_2_NesterovMomentum, label='NesterovMomentumOptimizer')
# plt.plot(data_3_2_2_QNG, label='QNGOptimizer')
plt.plot(data_3_2_2_RMSProp, label='RMSPropOptimizer')

plt.title('N2H4 ADAPT-VQE Custom Optimizer')
plt.legend()
plt.show()

# %%
plt.plot(data_3_2_2_Adagrad, label='data_3_2_2_Adagrad')
plt.plot(data_3_2_2_Adam, label='data_3_2_2_Adam')
plt.plot(data_3_2_2_GradientDescent, label='data_3_2_2_GradientDescent')
plt.plot(data_3_2_2_Momentum, label='data_3_2_2_Momentum')
plt.plot(data_3_2_2_NesterovMomentum, label='data_3_2_2_NesterovMomentum')
plt.plot(data_3_2_2_QNG, label='data_3_2_2_QNG')
plt.plot(data_3_2_2_RMSProp, label='data_3_2_2_RMSProp')

plt.title('N2H4 ADAPT-VQE Custom Optimizer')
plt.legend()
plt.show()

# %% [markdown]
# ### VQE Classical Optimizer (Active Space 8,8)

# %%
data_3_8_8_Adam = np.loadtxt('N2H4_3_8_8_AdamOptimizer.txt', delimiter=',')
data_3_8_8_Adagrad = np.loadtxt('N2H4_3_8_8_AdagradOptimizer.txt', delimiter=',')
data_3_8_8_GradientDescent = np.loadtxt('N2H4_3_8_8_GradientDescentOptimizer.txt', delimiter=',')
data_3_8_8_Momentum = np.loadtxt('N2H4_3_8_8_MomentumOptimizer.txt', delimiter=',')
data_3_8_8_NesterovMomentum = np.loadtxt('N2H4_3_8_8_NesterovMomentumOptimizer.txt', delimiter=',')
data_3_8_8_QNG = np.loadtxt('N2H4_3_8_8_QNGOptimizer.txt', delimiter=',')
data_3_8_8_RMSProp = np.loadtxt('N2H4_3_8_8_RMSPropOptimizer.txt', delimiter=',')

# %%
plt.plot(data_3_8_8_Adagrad, label='AdagradOptimizer')
# plt.plot(data_3_8_8_Adam, label='AdamOptimizer')
plt.plot(data_3_8_8_GradientDescent, label='GradientDescentOptimizer')
plt.plot(data_3_8_8_Momentum, label='MomentumOptimizer')
# plt.plot(data_3_8_8_NesterovMomentum, label='NesterovMomentumOptimizer')
# plt.plot(data_3_8_8_QNG, label='QNGOptimizer')
plt.plot(data_3_8_8_RMSProp, label='RMSPropOptimizer')

plt.title('N2H4 ADAPT-VQE Custom Optimizer')
plt.xlabel("ADAPT Iteration")
plt.ylabel("Energy")
plt.legend()
plt.show()

# %%
# plt.plot(data_3_8_8_Adagrad, label='AdagradOptimizer')
# plt.plot(data_3_8_8_Adam, label='AdamOptimizer')
# plt.plot(data_3_8_8_GradientDescent, label='GradientDescentOptimizer')
# plt.plot(data_3_8_8_Momentum, label='MomentumOptimizer')
# plt.plot(data_3_8_8_NesterovMomentum, label='NesterovMomentumOptimizer')
plt.plot(data_3_8_8_QNG, label='QNGOptimizer')
# plt.plot(data_3_8_8_RMSProp, label='RMSPropOptimizer')

plt.title('N2H4 ADAPT-VQE QNG Optimizer')
plt.xlabel("ADAPT Iteration")
plt.ylabel("Energy")
plt.legend()
plt.show()

# %%
plt.plot(data_3_8_8_Adam, label='AdamOptimizer')

plt.title('N2H4 ADAPT-VQE AdamOptimizer')
plt.xlabel("ADAPT Iteration")
plt.ylabel("Energy")
plt.legend()
plt.show()
