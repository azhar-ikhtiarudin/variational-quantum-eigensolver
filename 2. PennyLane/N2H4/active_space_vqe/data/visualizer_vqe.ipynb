# %%
import numpy as np
import matplotlib.pyplot as plt
au_to_kcal_conversion = 627.509474

# %%
vqe_50_2_2 = np.loadtxt('N2H4_50_2_2.txt', delimiter=',')
vqe_100_2_2 = np.loadtxt('N2H4_100_2_2.txt', delimiter=',')
vqe_50_4_4 = np.loadtxt('N2H4_50_4_4.txt', delimiter=',')
vqe_50_6_6 = np.loadtxt('N2H4_50_6_6.txt', delimiter=',')

# %%
# plt.plot(vqe_100_2_2)
plt.plot(vqe_50_2_2, label='2 2')
plt.plot(vqe_50_4_4, label='4 4')
plt.plot(vqe_50_6_6, label='6 6')
plt.legend()

# %%
vqe_52_2_2 = np.loadtxt('N2H4_52_2_2.txt', delimiter=',')
vqe_53_2_2 = np.loadtxt('N2H4_53_2_2.txt', delimiter=',')
vqe_58_2_2 = np.loadtxt('N2H4_58_2_2.txt', delimiter=',')
vqe_59_2_2 = np.loadtxt('N2H4_59_2_2.txt', delimiter=',')

plt.plot(vqe_52_2_2)
# plt.plot(vqe_53_2_2)
plt.plot(vqe_58_2_2)
plt.plot(vqe_59_2_2)

# %%
vqe_120_2_2 = np.loadtxt('N2H4_120_2_2.txt', delimiter=',')
vqe_300_4_4 = np.loadtxt('N2H4_300_4_4.txt', delimiter=',')
vqe_300_6_6 = np.loadtxt('N2H4_300_6_6.txt', delimiter=',')

plt.plot(vqe_120_2_2)
plt.plot(vqe_300_4_4)
plt.plot(vqe_300_6_6)
