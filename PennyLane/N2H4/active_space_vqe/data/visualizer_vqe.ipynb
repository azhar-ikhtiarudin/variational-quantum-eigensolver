# %%
import numpy as np
import matplotlib.pyplot as plt
au_to_kcal_conversion = 627.509474

# %%
vqe_50_2_2 = np.loadtxt('N2H4_50_2_2.txt', delimiter=',')
vqe_100_2_2 = np.loadtxt('N2H4_100_2_2.txt', delimiter=',')
vqe_50_4_4 = np.loadtxt('N2H4_50_4_4.txt', delimiter=',')

# %%
# plt.plot(vqe_100_2_2)
plt.plot(vqe_50_2_2)
plt.plot(vqe_50_4_4)
