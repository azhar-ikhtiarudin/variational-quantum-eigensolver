# %%
import pyscf
import numpy as np
import matplotlib.pyplot as plt

# %%
coordinates = {}

coordinates[0]  = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.334639 0.680561 -0.254663 ; H -0.605017 1.230432 0.554843 ; H 0.373523 1.230432 -0.731012 "
coordinates[1]  = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.355554 0.723096 -0.270579 ; H -0.625932 1.272967 0.538927 ; H 0.352608 1.272967 -0.746928 "
coordinates[2]  = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.376469 0.765631 -0.286495 ; H -0.646847 1.315502 0.52301 ; H 0.331694 1.315502 -0.762845 "
coordinates[3]  = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.397384 0.808166 -0.302412 ; H -0.667762 1.358037 0.507094 ; H 0.310779 1.358037 -0.778761 "
coordinates[4]  = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.418299 0.850701 -0.318328 ; H -0.688677 1.400572 0.491177 ; H 0.289864 1.400572 -0.794678 "
coordinates[5]  = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.439214 0.893236 -0.334245 ; H -0.709592 1.443107 0.475261 ; H 0.268949 1.443107 -0.810594 "
coordinates[6]  = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.460129 0.935771 -0.350161 ; H -0.730507 1.485643 0.459345 ; H 0.248034 1.485643 -0.82651 "
coordinates[7]  = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.481044 0.978307 -0.366078 ; H -0.751422 1.528178 0.443428 ; H 0.227119 1.528178 -0.842427 "
coordinates[8]  = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.501959 1.020842 -0.381994 ; H -0.772337 1.570713 0.427512 ; H 0.206204 1.570713 -0.858343 "
coordinates[9]  = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.522874 1.063377 -0.39791 ; H -0.793252 1.613248 0.411595 ; H 0.185289 1.613248 -0.87426 "
coordinates[10] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.543789 1.105912 -0.413827 ; H -0.814167 1.655783 0.395679 ; H 0.164374 1.655783 -0.890176 "
coordinates[11] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.564704 1.148447 -0.429743 ; H -0.835082 1.698318 0.379763 ; H 0.143459 1.698318 -0.906092 "
coordinates[12] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.585619 1.190982 -0.44566 ; H -0.855997 1.740853 0.363846 ; H 0.122544 1.740853 -0.922009 "
coordinates[13] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.606534 1.233517 -0.461576 ; H -0.876912 1.783388 0.34793 ; H 0.101629 1.783388 -0.937925 "
coordinates[14] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.627449 1.276052 -0.477492 ; H -0.897827 1.825923 0.332013 ; H 0.080714 1.825923 -0.953842 "
coordinates[15] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.648364 1.318587 -0.493409 ; H -0.918742 1.868458 0.316097 ; H 0.059799 1.868458 -0.969758 "
coordinates[16] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.669279 1.361122 -0.509325 ; H -0.939657 1.910993 0.30018 ; H 0.038884 1.910993 -0.985675 "
coordinates[17] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.690194 1.403657 -0.525242 ; H -0.960572 1.953528 0.284264 ; H 0.017969 1.953528 -1.001591 "
coordinates[18] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.711109 1.446192 -0.541158 ; H -0.981487 1.996063 0.268348 ; H -0.002946 1.996063 -1.017507 "
coordinates[19] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.732024 1.488727 -0.557075 ; H -1.002402 2.038598 0.252431 ; H -0.023861 2.038598 -1.033424 "
coordinates[20] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.752939 1.531262 -0.572991 ; H -1.023317 2.081133 0.236515 ; H -0.044776 2.081133 -1.04934 "
coordinates[21] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.773854 1.573797 -0.588907 ; H -1.044232 2.123669 0.220598 ; H -0.065691 2.123669 -1.065257 "
coordinates[22] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.794769 1.616333 -0.604824 ; H -1.065147 2.166204 0.204682 ; H -0.086606 2.166204 -1.081173 "
coordinates[23] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.815684 1.658868 -0.62074 ; H -1.086062 2.208739 0.188766 ; H -0.107521 2.208739 -1.097089 "
coordinates[24] = "N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.836599 1.701403 -0.636657 ; H -1.106977 2.251274 0.172849 ; H -0.128436 2.251274 -1.113006 "

# %%
def calc_fci_N2H4(i):
    mol = pyscf.M(
        # atom = f'Li 0 0 0; H 0 0 {r}',  # in Angstrom
        # atom = 'N 0.0 0.0 0.0; H 0.0 0.0 1.015264; H 0.978541 0.0 -0.270591; N -0.334639 0.680561 -0.254663; H -0.605017 1.230432 0.554843; H 0.373523, 1.230432, -0.731012',
        atom = coordinates[i],
        basis = 'sto-3g',
        # symmetry = True,
    )
    myhf = mol.RHF().run()

    #
    # create an FCI solver based on the SCF object
    #
    cisolver = pyscf.fci.FCI(myhf)
    print('E(FCI) = %.12f' % cisolver.kernel()[0])
    return cisolver.kernel()[0]

# %%
E_1547 = calc_fci_N2H4(1.547)
# Out:
# /home/azhar04/anaconda3/envs/quantum-dev/lib/python3.8/site-packages/pyscf/dft/libxc.py:772: UserWarning: Since PySCF-2.3, B3LYP (and B3P86) are changed to the VWN-RPA variant, the same to the B3LYP functional in Gaussian and ORCA (issue 1480). To restore the VWN5 definition, you can put the setting "B3LYP_WITH_VWN5 = True" in pyscf_conf.py
#   warnings.warn('Since PySCF-2.3, B3LYP (and B3P86) are changed to the VWN-RPA variant, '
# converged SCF energy = -108.024118953572
# E(FCI) = -108.143687814520

# %%
print(E_1547)
# Out:
# -108.14368781452004

# %%
E_R = []
Data = []
for i in range(len(coordinates)):
    E = calc_fci_N2H4(i)
    E_R.append(E)
# Out:
# converged SCF energy = -108.024118953572
# E(FCI) = -108.143687814520
# converged SCF energy = -108.447596458659
# E(FCI) = -108.562803202069
# converged SCF energy = -108.773786876888
# E(FCI) = -108.886709186330
# converged SCF energy = -109.02447335153
# E(FCI) = -109.136129302856
# converged SCF energy = -109.216482831212
# E(FCI) = -109.327524900980
# converged SCF energy = -109.362845995284
# E(FCI) = -109.473763166598
# converged SCF energy = -109.473649238206
# E(FCI) = -109.584850159224
# converged SCF energy = -109.556703287159
# E(FCI) = -109.668556244917
# converged SCF energy = -109.618047921566
# E(FCI) = -109.730902412498
# converged SCF energy = -109.662363518717
# E(FCI) = -109.776562329130
# converged SCF energy = -109.693275264805
# E(FCI) = -109.809162428931
# converged SCF energy = -109.713596870726
# E(FCI) = -109.831522972470
# converged SCF energy = -109.725520325544
# E(FCI) = -109.845846996115
# converged SCF energy = -109.730762022275
# ...

# %%
plt.plot(E_R)

# %%
# fci_data_LiH = np.column_stack((r_array, E_R))
file_name = 'fci_data_N2H4.txt'
np.savetxt(file_name, E_R, delimiter=',', header='E_R', comments='')
