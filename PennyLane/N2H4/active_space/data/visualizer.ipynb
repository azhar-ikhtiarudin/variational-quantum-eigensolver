# %%
import numpy as np
import matplotlib.pyplot as plt
au_to_kcal_conversion = 627.509474

# %% [markdown]
# ### Adapt VQE

# %%
data_3_2_2 = np.loadtxt('N2H4_3_2_2.txt', delimiter=',')
data_3_2_4 = np.loadtxt('N2H4_3_2_4.txt', delimiter=',')
data_3_4_4 = np.loadtxt('N2H4_3_4_4.txt', delimiter=',')
data_3_4_6 = np.loadtxt('N2H4_3_4_6.txt', delimiter=',')
data_3_6_4 = np.loadtxt('N2H4_3_6_4.txt', delimiter=',')
data_3_6_6 = np.loadtxt('N2H4_3_6_6.txt', delimiter=',')
data_3_6_8 = np.loadtxt('N2H4_3_6_8.txt', delimiter=',')

data_3_8_5 = np.loadtxt('N2H4_3_8_5.txt', delimiter=',')
data_3_8_6 = np.loadtxt('N2H4_3_8_6.txt', delimiter=',')
data_3_8_7 = np.loadtxt('N2H4_3_8_7.txt', delimiter=',')
data_3_8_8 = np.loadtxt('N2H4_3_8_8.txt', delimiter=',')

data_3_10_6 = np.loadtxt('N2H4_3_10_6.txt', delimiter=',')
data_3_10_7 = np.loadtxt('N2H4_3_10_7.txt', delimiter=',')
data_3_10_8 = np.loadtxt('N2H4_3_10_8.txt', delimiter=',')

data_3_12_7 = np.loadtxt('N2H4_3_12_7.txt', delimiter=',')
data_3_12_8 = np.loadtxt('N2H4_3_12_8.txt', delimiter=',')

# %%
plt.plot(data_3_8_5, label="Active Space 8 5")
plt.plot(data_3_8_6[:30], label="Active Space 8 6")
plt.plot(data_3_8_7[:33], label="Active Space 8 7")
plt.plot(data_3_8_8, label="Active Space 8 8")

plt.title('N2H4 ADAPT-VQE (Active Electron = 8)')
plt.legend()
plt.show()

# %%
plt.plot(data_3_10_6, label="Active Space 10 6")
plt.plot(data_3_10_7[:35], label="Active Space 10 7")
plt.plot(data_3_10_8, label="Active Space 10 8")
plt.title('N2H4 ADAPT-VQE (Active Electron = 10)')
plt.legend()
plt.show()

# %%
plt.plot(data_3_12_7, label="Active Space 12 7")
plt.plot(data_3_12_8, label="Active Space 12 8")

plt.title('N2H4 ADAPT-VQE (Active Electron = 12)')
plt.legend()
plt.show()

# %%
plt.plot(data_3_2_4, label="Active Space 2 4")
plt.plot(data_3_4_4, label="Active Space 4 4")
plt.plot(data_3_6_4, label="Active Space 6 4")

plt.title('N2H4 ADAPT-VQE (Active Orbital = 4)')
plt.legend()
plt.show()

# %%
plt.plot(data_3_4_6[:40], label="Active Space 4 6")
plt.plot(data_3_6_6[:40], label="Active Space 6 6")
plt.plot(data_3_8_6[:40], label="Active Space 8 6")
plt.plot(data_3_10_6, label="Active Space 10 6")

plt.title('N2H4 ADAPT-VQE (Active Orbital = 6)')
plt.legend()
plt.show()

# %%
plt.plot(data_3_6_8[:40], label="Active Space 6 8")
plt.plot(data_3_8_8[:40], label="Active Space 8 8")
plt.plot(data_3_10_8[:40], label="Active Space 10 8")
plt.plot(data_3_12_8, label="Active Space 12 8")

plt.title('N2H4 ADAPT-VQE (Active Orbital = 8)')
plt.legend()
plt.show()

# %%
plt.plot(data_3_2_2, label="Active Space 2 2", marker=">", markersize=5)
plt.plot(data_3_2_4, label="Active Space 2 4", marker=">", markersize=5)

plt.plot(data_3_4_4[:40], label="Active Space 4 4", marker="<", markersize=5)
plt.plot(data_3_4_6[:40], label="Active Space 4 6", marker="<", markersize=5)

plt.plot(data_3_6_4, label="Active Space 6 4", marker="s", markersize=5)
plt.plot(data_3_6_6[:40], label="Active Space 6 6", marker="s", markersize=5)
plt.plot(data_3_6_8, label="Active Space 6 8", marker="s", markersize=5)

plt.plot(data_3_8_5, label="Active Space 8 5", marker="o", markersize=5)
plt.plot(data_3_8_6[:40], label="Active Space 8 6", marker="o", markersize=1)
plt.plot(data_3_8_7[:40], label="Active Space 8 7", marker="o", markersize=5)
plt.plot(data_3_8_8, label="Active Space 8 8", marker="o", markersize=5)

plt.plot(data_3_10_6, label="Active Space 10 6", marker="x", markersize=5)
plt.plot(data_3_10_7[:40], label="Active Space 10 7", marker="x", markersize=5)
plt.plot(data_3_10_8, label="Active Space 10 8", marker="x", markersize=5)

plt.plot(data_3_12_7, label="Active Space 12 7", marker="*", markersize=5)
plt.plot(data_3_12_8, label="Active Space 12 8", marker="*", markersize=5)

plt.title('N2H4 ADAPT-VQE')
# plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., ncol=1)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(data_3_2_2, label="Active Space 2 2")
# plt.plot(data_3_2_4, label="Active Space 2 4")
plt.plot(data_3_4_4, label="Active Space 4 4")
# plt.plot(data_3_4_6[:35], label="Active Space 4 6")
# plt.plot(data_3_6_4, label="Active Space 6 4")
plt.plot(data_3_6_6[:34], label="Active Space 6 6")
# plt.plot(data_3_6_8, label="Active Space 6 8")
# plt.plot(data_3_8_7[:35], label="Active Space 8 7")
plt.plot(data_3_8_8, label="Active Space 8 8")
# plt.plot(data_3_10_8, label="Active Space 10 8")
# plt.axhline(y=-109.73067811, color='r', linestyle='--', label='HF Energy -109.7307')
# plt.axhline(y=-109.85695386832232, color='r', linestyle='--', label='FCI Energy (-109.8569)')

# plt.title('N2H4 ADAPT-VQE')
plt.legend()
plt.show()

# %%
plt.plot(data_3_8_7, label="Active Space 8 7")
plt.plot(data_3_8_8, label="Active Space 8 8")

# %%
plt.plot(data_3_8_5, label="Active Space 8 5")
plt.plot(data_3_8_6, label="Active Space 8 6")
plt.plot(data_3_8_7, label="Active Space 8 7")
plt.plot(data_3_8_8, label="Active Space 8 8")

plt.title('N2H4 ADAPT-VQE (Active Electron = 8)')
plt.legend()
plt.show()

# %% [markdown]
# ### VQE

# %%
vqe_2_2 = np.loadtxt('N2H4_VQE_1e-10_2_2.txt', delimiter=',')
vqe_2_4 = np.loadtxt('N2H4_VQE_1e-10_2_4.txt', delimiter=',')
vqe_4_4 = np.loadtxt('N2H4_VQE_1e-10_4_4.txt', delimiter=',')
vqe_4_6 = np.loadtxt('N2H4_VQE_1e-10_4_6.txt', delimiter=',')
vqe_6_6 = np.loadtxt('N2H4_VQE_1e-10_6_6.txt', delimiter=',')
vqe_8_8 = np.loadtxt('N2H4_VQE_1e-10_8_8.txt', delimiter=',')
vqe_10_10 = np.loadtxt('N2H4_VQE_1e-10_10_10.txt', delimiter=',')

# %%
plt.plot(vqe_2_2, label="Active Space 2 2")
# plt.plot(vqe_2_4, label="Active Space 2 4")
plt.plot(vqe_4_4, label="Active Space 4 4")
plt.plot(vqe_4_6, label="Active Space 4 6")
plt.plot(vqe_6_6, label="Active Space 6 6")
plt.plot(vqe_8_8, label="Active Space 8 8")
plt.plot(vqe_10_10, label="Active Space 10 10")
# plt.axhline(y=-109.73067811, color='r', linestyle='--', label='HF Energy -109.7307')
# plt.axhline(y=-109.85695386832232, color='r', linestyle='--', label='FCI Energy (-109.8569)')

plt.title('N2H4 VQE - Active Space Analysis (without reference)')
plt.legend()
plt.show()

# %% [markdown]
# ### Ground State

# %%
import matplotlib.pyplot as plt

plt.plot(data_3_2_4, label="Active Space 2 4")
plt.plot(data_3_4_4, label="Active Space 4 4")
plt.plot(data_3_6_4, label="Active Space 6 4")
# plt.axhline(y=-109.85695386832232, color='r', linestyle='--', label='Horizontal Line at -109.86')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(data_3_2_4, label="Active Space 2 4")
plt.plot(data_3_4_4, label="Active Space 4 4")
plt.plot(data_3_6_4, label="Active Space 6 4")
plt.plot(data_3_6_6, label="Active Space 6 6")
# plt.axhline(y=-109.85695386832232, color='r', linestyle='--', label='Horizontal Line at -109.86')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(data_3_2_2, label="Active Space 2 4")
plt.plot(data_3_4_4, label="Active Space 4 4")
plt.plot(data_3_6_6[:30], label="Active Space 6 4")
plt.plot(data_3_8_8, label="Active Space 6 6")
plt.axhline(y=-109.85695386832232, color='r', linestyle='--', label='FCI')
plt.legend()

plt.show()

# %%
fci = -109.85695386832232
au_to_kcal_conversion = 627.509474
print("FCI: ", fci)
print("ADAPT-VQE 8 8", data_3_8_8[-1], "\n")
print("Persen Error (%): ", abs(data_3_8_8[-1]-fci)/abs(fci)*100,"%")
print("Batas chemical accuracy): ",abs(data_3_8_8[-1]-fci) * au_to_kcal_conversion, 'kcal/mol')
# Out:
# FCI:  -109.85695386832232
# ADAPT-VQE 8 8 -109.7641234
#
# Persen Error (%):  0.08450122186492459 %
# Batas chemical accuracy):  58.25199834811199 kcal/mol
