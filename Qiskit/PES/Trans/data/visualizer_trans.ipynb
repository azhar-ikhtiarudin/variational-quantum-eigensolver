# %%
import numpy as np
import matplotlib.pyplot as plt
au_to_kcal_conversion = 627.509474

# %%
Trans_VQE = np.loadtxt('Trans_VQE_2_2.txt', delimiter=',')
Trans_AdVQE = np.loadtxt('Trans_AdVQE_2_2.txt', delimiter=',')

plt.plot(Trans_VQE, label="Trans VQE 2 2")
plt.plot(Trans_AdVQE, label="Trans AdVQE 2 2", linestyle='', marker="o")

plt.legend()

# %%
delta = Trans_AdVQE - Trans_VQE
plt.plot(delta)
