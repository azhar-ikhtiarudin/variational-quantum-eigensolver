# %%
# General imports
import numpy as np

# Pre-defined ansatz circuit and operator class for Hamiltonian
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp

# SciPy minimizer routine
from scipy.optimize import minimize

# Plotting functions
import matplotlib.pyplot as plt

# %%
# runtime imports
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator

# To run on hardware, select the backend with the fewest number of jobs in the queue
service = QiskitRuntimeService(channel="ibm_quantum")
backend = service.least_busy(operational=True, simulator=False)
backend.name
# Out:
# 'ibm_osaka'

# %%
import qiskit_ibm_runtime

qiskit_ibm_runtime.version.get_version_info()
# Out:
# '0.23.0'

# %% [markdown]
# ## Step 1: Map classical inputs to a quantum problem

# %%
# hamiltonian = SparsePauliOp.from_list(
#     [("YZ", 0.3980), ("ZI", -0.3980), ("ZZ", -0.0113), ("XX", 0.1810)]
# )

hamiltonian = SparsePauliOp.from_list(
    [("IIII", -0.0996), 
     ("IIIZ", 0.1711), 
     ("IIZI", 0.1711), 
     ("IZII", -0.2225), 
     ("ZIII", -0.2225), 
     ("IIZZ", 0.1686), 
     ("IZIZ", 0.1205), 
     ("ZIIZ", 0.1658), 
     ("IZZI", 0.1658), 
     ("ZIZI", 0.1205), 
     ("ZZII", 0.1743), 
     ("XYYX", 0.0453), 
     ("YXXY", 0.0453), 
     ("YYXX", -0.0453), 
     ("XXYY", -0.0453)]
)

# %%
hamiltonian
# Out:
# SparsePauliOp(['IIII', 'IIIZ', 'IIZI', 'IZII', 'ZIII', 'IIZZ', 'IZIZ', 'ZIIZ', 'IZZI', 'ZIZI', 'ZZII', 'XYYX', 'YXXY', 'YYXX', 'XXYY'],
#               coeffs=[-0.0996+0.j,  0.1711+0.j,  0.1711+0.j, -0.2225+0.j, -0.2225+0.j,
#   0.1686+0.j,  0.1205+0.j,  0.1658+0.j,  0.1658+0.j,  0.1205+0.j,
#   0.1743+0.j,  0.0453+0.j,  0.0453+0.j, -0.0453+0.j, -0.0453+0.j])

# %%
ansatz = EfficientSU2(hamiltonian.num_qubits)
ansatz.decompose().draw("mpl", style="iqp")

# %%
from qiskit.circuit.library import TwoLocal

entangler_map = [[0, 1], [1, 2], [2,3], [3,0]]  # entangle the first and last two-way
ansatz = TwoLocal(hamiltonian.num_qubits, 'ry', 'cx', entangler_map, reps=1, skip_final_rotation_layer=True)

ansatz.decompose().draw("mpl", style="iqp")

# %%
num_params = ansatz.num_parameters
num_params
# Out:
# 4

# %% [markdown]
# ## Step 2: Optimize problem for quantum execution.

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(ansatz)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# ## Step 3: Execute using Qiskit Primitives.

# %% [markdown]
# ### Nelder-Mead Optimizer

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

def cost_func(params, ansatz, hamiltonian, estimator):
    """Return estimate of energy from estimator

    Parameters:
        params (ndarray): Array of ansatz parameters
        ansatz (QuantumCircuit): Parameterized ansatz circuit
        hamiltonian (SparsePauliOp): Operator representation of Hamiltonian
        estimator (EstimatorV2): Estimator primitive instance
        cost_history_dict: Dictionary for storing intermediate results

    Returns:
        float: Energy estimate
    """
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")

    return energy

# %%
x0 = 2 * np.pi * np.random.random(num_params)
x0
# Out:
# array([2.91915334, 1.73936636, 2.94509516, 1.05496598])

# %%
with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    estimator.options.default_shots = 200

    res = minimize(
        cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="Nelder-Mead",
    )
# Out:
# Iters. done: 1 [Current cost: -0.2880398470054028]
# Iters. done: 2 [Current cost: -0.24508055761363395]
# Iters. done: 3 [Current cost: -0.17925003325837646]
# Iters. done: 4 [Current cost: -0.1293468176055972]
# Iters. done: 5 [Current cost: -0.2872017000103495]
# Iters. done: 6 [Current cost: -0.25810488572124846]
# Iters. done: 7 [Current cost: -0.278375218453466]
# Iters. done: 8 [Current cost: -0.2407303390386556]
# Iters. done: 9 [Current cost: -0.19231138656327215]
# Iters. done: 10 [Current cost: -0.27084776694176327]
# Iters. done: 11 [Current cost: -0.2679745380952293]
# Iters. done: 12 [Current cost: -0.2303498673372928]
# Iters. done: 13 [Current cost: -0.1392957854268212]
# Iters. done: 14 [Current cost: -0.22169081217723066]
# Iters. done: 15 [Current cost: -0.24564753236146852]
# Iters. done: 16 [Current cost: -0.259933642120588]
# Iters. done: 17 [Current cost: -0.24884554599267705]
# Iters. done: 18 [Current cost: -0.2317644854624395]
# Iters. done: 19 [Current cost: -0.11507921568125326]
# Iters. done: 20 [Current cost: -0.16899299081960067]
# Iters. done: 21 [Current cost: -0.2506773884656266]
# Iters. done: 22 [Current cost: -0.24968377399837283]
# Iters. done: 23 [Current cost: -0.1961750582929155]
# Iters. done: 24 [Current cost: -0.21334093146743804]
# Iters. done: 25 [Current cost: -0.20431408705144583]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 5
#       2 estimator = Estimator(session=session)
#       3 estimator.options.default_shots = 200
# ----> 5 res = minimize(
#       6     cost_func,
#       7     x0,
#       8     args=(ansatz_isa, hamiltonian_isa, estimator),
#       9     method="Nelder-Mead",
#      10 )
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/scipy/optimize/_minimize.py:701, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     698 callback = _wrap_callback(callback, meth)
#     700 if meth == 'nelder-mead':
# --> 701     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     702                                **options)
#     703 elif meth == 'powell':
#     704     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/scipy/optimize/_optimize.py:868, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     866 if bounds is not None:
#     867     xc = np.clip(xc, lower_bound, upper_bound)
# --> 868 fxc = func(xc)
#     870 if fxc <= fxr:
#     871     sim[-1] = xc
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/scipy/optimize/_optimize.py:526, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     524 ncalls[0] += 1
#     525 # A copy of x is sent to the user function (gh13740)
# --> 526 fx = function(np.copy(x), *(wrapper_args + args))
#     527 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     528 # backwards-compatibility, also allow np.array([1.3]),
#     529 # np.array([[1.3]]) etc.
#     530 if not np.isscalar(fx):
#
# Cell In[17], line 21, in cost_func(params, ansatz, hamiltonian, estimator)
#       8 """Return estimate of energy from estimator
#       9
#      10 Parameters:
#    (...)
#      18     float: Energy estimate
#      19 """
#      20 pub = (ansatz, [hamiltonian], [params])
# ---> 21 result = estimator.run(pubs=[pub]).result()
#      22 energy = result[0].data.evs[0]
#      24 cost_history_dict["iters"] += 1
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/qiskit_ibm_runtime/runtime_job_v2.py:135, in RuntimeJobV2.result(self, timeout, decoder)
#     120 """Return the results of the job.
#     121
#     122 Args:
#    (...)
#     132     RuntimeInvalidStateError: If the job was cancelled, and attempting to retrieve result.
#     133 """
#     134 _decoder = decoder or self._final_result_decoder
# --> 135 self.wait_for_final_state(timeout=timeout)
#     136 if self._status == "ERROR":
#     137     error_message = self._reason if self._reason else self._error_message
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/qiskit_ibm_runtime/runtime_job_v2.py:255, in RuntimeJobV2.wait_for_final_state(self, timeout)
#     253     self._ws_client_future = self._executor.submit(self._start_websocket_client)
#     254 if self._is_streaming():
# --> 255     self._ws_client_future.result(timeout)
#     256 # poll for status after stream has closed until status is final
#     257 # because status doesn't become final as soon as stream closes
#     258 status = self.status()
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
cost_history_dict
plt.plot(cost_history_dict['cost_history'])

# %% [markdown]
# ### COBYLA

# %%
with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    estimator.options.default_shots = 200

    res = minimize(
        cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
    )
# Out:
# Iters. done: 26 [Current cost: -0.20393760377761488]
# Iters. done: 27 [Current cost: -0.19785614011850605]
# Iters. done: 28 [Current cost: 0.08795246401395772]
# Iters. done: 29 [Current cost: -0.13775712706493212]
# Iters. done: 30 [Current cost: -0.43052918367014026]
# Iters. done: 31 [Current cost: -0.5230726536643745]
# Iters. done: 32 [Current cost: -0.43349552489378973]
# Iters. done: 33 [Current cost: -0.5365944293074614]
# Iters. done: 34 [Current cost: -0.5009373050451049]
# Iters. done: 35 [Current cost: -0.4448438985543533]
# capi_return is NULL
# Call-back cb_calcfc_in__cobyla__user__routines failed.
# ---------------------------------------------------------------------------
# IBMRuntimeError                           Traceback (most recent call last)
# Cell In[25], line 5
#       2 estimator = Estimator(session=session)
#       3 estimator.options.default_shots = 200
# ----> 5 res = minimize(
#       6     cost_func,
#       7     x0,
#       8     args=(ansatz_isa, hamiltonian_isa, estimator),
#       9     method="cobyla",
#      10 )
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/scipy/optimize/_minimize.py:719, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     716     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     717                         **options)
#     718 elif meth == 'cobyla':
# --> 719     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     720                            bounds=bounds, **options)
#     721 elif meth == 'slsqp':
#     722     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     723                           constraints, callback=callback, **options)
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:293, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     290         callback(np.copy(x))
#     292 info = np.zeros(4, np.float64)
# --> 293 xopt, info = cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     294                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     295                               dinfo=info, callback=wrapped_callback)
#     297 if info[3] > catol:
#     298     # Check constraint violation
#     299     info[0] = 4
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:281, in _minimize_cobyla.<locals>.calcfc(x, con)
#     280 def calcfc(x, con):
# --> 281     f = sf.fun(x)
#     282     i = 0
#     283     for size, c in izip(cons_lengths, constraints):
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:278, in ScalarFunction.fun(self, x)
#     276 if not np.array_equal(x, self.x):
#     277     self._update_x_impl(x)
# --> 278 self._update_fun()
#     279 return self.f
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# Cell In[17], line 21, in cost_func(params, ansatz, hamiltonian, estimator)
#       8 """Return estimate of energy from estimator
#       9
#      10 Parameters:
#    (...)
#      18     float: Energy estimate
#      19 """
#      20 pub = (ansatz, [hamiltonian], [params])
# ---> 21 result = estimator.run(pubs=[pub]).result()
#      22 energy = result[0].data.evs[0]
#      24 cost_history_dict["iters"] += 1
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/qiskit_ibm_runtime/estimator.py:151, in EstimatorV2.run(self, pubs, precision)
#     137 """Submit a request to the estimator primitive.
#     138
#     139 Args:
#    (...)
#     148
#     149 """
#     150 coerced_pubs = [EstimatorPub.coerce(pub, precision) for pub in pubs]
# --> 151 return self._run(coerced_pubs)
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/qiskit_ibm_runtime/base_primitive.py:163, in BasePrimitiveV2._run(self, pubs)
#     160 logger.info("Submitting job using options %s", primitive_options)
#     162 if self._session:
# --> 163     return self._session.run(
#     164         program_id=self._program_id(),
#     165         inputs=primitive_inputs,
#     166         options=runtime_options,
#     167         callback=options_dict.get("environment", {}).get("callback", None),
#     168         result_decoder=DEFAULT_DECODERS.get(self._program_id()),
#     169     )
#     171 if self._backend:
#     172     runtime_options["backend"] = self._backend
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/qiskit_ibm_runtime/session.py:43, in _active_session.<locals>._wrapper(self, *args, **kwargs)
#      41 if not self._active:
#      42     raise RuntimeError("The session is closed.")
# ---> 43 return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/qiskit_ibm_runtime/session.py:201, in Session.run(self, program_id, inputs, options, callback, result_decoder)
#     198 options["backend"] = self._backend
#     200 if isinstance(self._service, QiskitRuntimeService):
# --> 201     job = self._service.run(
#     202         program_id=program_id,  # type: ignore[arg-type]
#     203         options=options,
#     204         inputs=inputs,
#     205         session_id=self._session_id,
#     206         start_session=False,
#     207         callback=callback,
#     208         result_decoder=result_decoder,
#     209     )
#     211     if self._backend is None:
#     212         self._backend = job.backend()
#
# File ~/anaconda3/envs/qiskit-1/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:884, in QiskitRuntimeService.run(self, program_id, inputs, options, callback, result_decoder, session_id, start_session)
#     882     if ex.status_code == 404:
#     883         raise RuntimeProgramNotFound(f"Program not found: {ex.message}") from None
# --> 884     raise IBMRuntimeError(f"Failed to run program: {ex}") from None
#     885 backend = (
#     886     self.backend(name=response["backend"], instance=hgp_name)
#     887     if response["backend"]
#     888     else qrt_options.get_backend_name()
#     889 )
#     891 if version == 2:
#
# IBMRuntimeError: 'Failed to run program: \'400 Client Error: Bad Request for url: https://api.quantum.ibm.com/runtime/jobs. {"errors":[{"code":1217,"message":"Session has been closed.","solution":"Reduce time between submitting subsequent jobs in a session.","more_info":"https://docs.quantum-computing.ibm.com/errors"}]}\''

# %%
print(len(cost_history_dict))
plt.plot(cost_history_dict['cost_history'])
# Out:
# 3

# %%
print(len(cost_history_dict))
plt.plot(cost_history_dict['cost_history'])
plt.ylim(-1.2, 0)
# Out:
# 3
# (-1.2, 0.0)

# %%
import matplotlib.pyplot as plt
cost = [0.14922586116758643, -0.11612803571621408, 0.07002776280206445, -0.13386988850633055, -0.3302387656462088, -0.10234731983003965, -0.13772207900026967, -0.45905039527309566, -0.445916509386791, -0.36337138067990404, -0.42997434693744946, -0.28915363465327376, -0.35322293062687277, -0.5704129149833769, -0.47988316089181043, -0.46759465876835415, -0.24320415638696258, -0.588662767522721, -0.44708847005466235, -0.5228542313152235]
plt.plot(cost)

# %% [markdown]
# ## Step 4: Post-process, return result in classical format.

# %%
all(cost_history_dict["prev_vector"] == res.x)

# %%
cost_history_dict["iters"] == res.nfev

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %%
cost_history_dict
# Out:
# {'prev_vector': array([3.05888996, 4.43727613, 5.39903657, 5.66676143, 3.91592233,
#         4.00972591, 4.42010001, 2.20419641, 1.54907842, 4.74382172,
#         1.6739801 , 4.65247405, 5.86036756, 4.70397595, 0.87260049,
#         1.27107314]),
#  'iters': 20,
#  'cost_history': [0.14922586116758643,
#   -0.11612803571621408,
#   0.07002776280206445,
#   -0.13386988850633055,
#   -0.3302387656462088,
#   -0.10234731983003965,
#   -0.13772207900026967,
#   -0.45905039527309566,
#   -0.445916509386791,
#   -0.36337138067990404,
#   -0.42997434693744946,
#   -0.28915363465327376,
#   -0.35322293062687277,
#   -0.5704129149833769,
#   -0.47988316089181043,
#   -0.46759465876835415,
#   -0.24320415638696258,
#   -0.588662767522721,
#   -0.44708847005466235,
#   -0.5228542313152235]}

# %%
plt.plot(cost_history_dict['cost_history'])
