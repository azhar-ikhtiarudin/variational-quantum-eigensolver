# %%
# !pip install qiskit-ibm-runtime
# Out:
# Collecting qiskit-ibm-runtime
#   Using cached qiskit_ibm_runtime-0.23.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: requests>=2.19 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from qiskit-ibm-runtime) (2.32.3)
# Collecting requests-ntlm>=1.1.0 (from qiskit-ibm-runtime)
#   Using cached requests_ntlm-1.2.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.13 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from qiskit-ibm-runtime) (1.26.4)
# Requirement already satisfied: urllib3>=1.21.1 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from qiskit-ibm-runtime) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from qiskit-ibm-runtime) (2.9.0)
# Requirement already satisfied: websocket-client>=1.5.1 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from qiskit-ibm-runtime) (1.8.0)
# Collecting ibm-platform-services>=0.22.6 (from qiskit-ibm-runtime)
#   Using cached ibm_platform_services-0.53.7-py3-none-any.whl
# Collecting pydantic (from qiskit-ibm-runtime)
#   Using cached pydantic-2.7.2-py3-none-any.whl.metadata (108 kB)
# Requirement already satisfied: qiskit>=1.0.0 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from qiskit-ibm-runtime) (1.1.0)
# Collecting ibm-cloud-sdk-core<4.0.0,>=3.19.2 (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime)
#   Using cached ibm_cloud_sdk_core-3.20.0-py3-none-any.whl
# Requirement already satisfied: six>=1.5 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime) (1.16.0)
# Requirement already satisfied: rustworkx>=0.14.0 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from qiskit>=1.0.0->qiskit-ibm-runtime) (0.14.2)
# Requirement already satisfied: scipy>=1.5 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from qiskit>=1.0.0->qiskit-ibm-runtime) (1.13.1)
# Requirement already satisfied: sympy>=1.3 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from qiskit>=1.0.0->qiskit-ibm-runtime) (1.12.1)
# Requirement already satisfied: dill>=0.3 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from qiskit>=1.0.0->qiskit-ibm-runtime) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from qiskit>=1.0.0->qiskit-ibm-runtime) (5.2.0)
# Requirement already satisfied: typing-extensions in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from qiskit>=1.0.0->qiskit-ibm-runtime) (4.12.1)
# Requirement already satisfied: symengine>=0.11 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from qiskit>=1.0.0->qiskit-ibm-runtime) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from requests>=2.19->qiskit-ibm-runtime) (2024.6.2)
# Collecting cryptography>=1.3 (from requests-ntlm>=1.1.0->qiskit-ibm-runtime)
#   Using cached cryptography-42.0.7-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting pyspnego>=0.1.6 (from requests-ntlm>=1.1.0->qiskit-ibm-runtime)
#   Using cached pyspnego-0.10.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting annotated-types>=0.4.0 (from pydantic->qiskit-ibm-runtime)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.18.3 (from pydantic->qiskit-ibm-runtime)
#   Using cached pydantic_core-2.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: cffi>=1.12 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (1.16.0)
# Collecting PyJWT<3.0.0,>=2.8.0 (from ibm-cloud-sdk-core<4.0.0,>=3.19.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime)
#   Using cached PyJWT-2.8.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from stevedore>=3.0.0->qiskit>=1.0.0->qiskit-ibm-runtime) (6.0.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from sympy>=1.3->qiskit>=1.0.0->qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: pycparser in /home/azhar04/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.22)
# Using cached qiskit_ibm_runtime-0.23.0-py3-none-any.whl (3.0 MB)
# Using cached requests_ntlm-1.2.0-py3-none-any.whl (6.0 kB)
# Using cached pydantic-2.7.2-py3-none-any.whl (409 kB)
# Using cached pydantic_core-2.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached cryptography-42.0.7-cp39-abi3-manylinux_2_28_x86_64.whl (3.8 MB)
# Using cached pyspnego-0.10.2-py3-none-any.whl (129 kB)
# Using cached PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Installing collected packages: PyJWT, pydantic-core, annotated-types, pydantic, ibm-cloud-sdk-core, cryptography, pyspnego, ibm-platform-services, requests-ntlm, qiskit-ibm-runtime
# Successfully installed PyJWT-2.8.0 annotated-types-0.7.0 cryptography-42.0.7 ibm-cloud-sdk-core-3.20.0 ibm-platform-services-0.53.7 pydantic-2.7.2 pydantic-core-2.18.3 pyspnego-0.10.2 qiskit-ibm-runtime-0.23.0 requests-ntlm-1.2.0

# %%
# General imports
import numpy as np

# Pre-defined ansatz circuit and operator class for Hamiltonian
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp

# SciPy minimizer routine
from scipy.optimize import minimize

# Plotting functions
import matplotlib.pyplot as plt

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
 
# Save an IBM Quantum account and set it as your default account.
# QiskitRuntimeService.save_account(channel="ibm_quantum", token="3938ec2167453e68ce3646104524ba97ba6ac764a519f4d27ae60605457a2573c9c1ae623c61938e759da0b428b13897be8a891a6740628557d539870d873c48")
 
# Load saved credentials
# service = QiskitRuntimeService()

service = QiskitRuntimeService(channel="ibm_quantum", token="3938ec2167453e68ce3646104524ba97ba6ac764a519f4d27ae60605457a2573c9c1ae623c61938e759da0b428b13897be8a891a6740628557d539870d873c48")

# %%
# runtime imports
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator

# To run on hardware, select the backend with the fewest number of jobs in the queue
# service = QiskitRuntimeService(channel="ibm_quantum")
backend = service.least_busy(operational=True, simulator=False)
backend.name
# Out:
# 'ibm_sherbrooke'

# %%
import qiskit_ibm_runtime

qiskit_ibm_runtime.version.get_version_info()
# Out:
# '0.23.0'

# %% [markdown]
# ## Step 1: Map classical inputs to a quantum problem

# %%
# hamiltonian = SparsePauliOp.from_list(
#     [("YZ", 0.3980), ("ZI", -0.3980), ("ZZ", -0.0113), ("XX", 0.1810)]
# )

hamiltonian = SparsePauliOp.from_list(
    [("IIII", -0.0996), 
     ("IIIZ", 0.1711), 
     ("IIZI", 0.1711), 
     ("IZII", -0.2225), 
     ("ZIII", -0.2225), 
     ("IIZZ", 0.1686), 
     ("IZIZ", 0.1205), 
     ("ZIIZ", 0.1658), 
     ("IZZI", 0.1658), 
     ("ZIZI", 0.1205), 
     ("ZZII", 0.1743), 
     ("XYYX", 0.0453), 
     ("YXXY", 0.0453), 
     ("YYXX", -0.0453), 
     ("XXYY", -0.0453)]
)

# %%
hamiltonian
# Out:
# SparsePauliOp(['IIII', 'IIIZ', 'IIZI', 'IZII', 'ZIII', 'IIZZ', 'IZIZ', 'ZIIZ', 'IZZI', 'ZIZI', 'ZZII', 'XYYX', 'YXXY', 'YYXX', 'XXYY'],
#               coeffs=[-0.0996+0.j,  0.1711+0.j,  0.1711+0.j, -0.2225+0.j, -0.2225+0.j,
#   0.1686+0.j,  0.1205+0.j,  0.1658+0.j,  0.1658+0.j,  0.1205+0.j,
#   0.1743+0.j,  0.0453+0.j,  0.0453+0.j, -0.0453+0.j, -0.0453+0.j])

# %%
# ansatz = EfficientSU2(hamiltonian.num_qubits)
# ansatz.decompose().draw("mpl", style="iqp")

# %%
from qiskit.circuit.library import TwoLocal

entangler_map = [[0, 1], [1, 2], [2,3], [3,0]]  # entangle the first and last two-way
ansatz = TwoLocal(hamiltonian.num_qubits, 'ry', 'cx', entangler_map, reps=1, skip_final_rotation_layer=True)

ansatz.decompose().draw("mpl", style="iqp")

# %%
num_params = ansatz.num_parameters
num_params
# Out:
# 4

# %% [markdown]
# ## Step 2: Optimize problem for quantum execution.

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(ansatz)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# ## Step 3: Execute using Qiskit Primitives.

# %% [markdown]
# ### COBYLA Optimizer

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

def cost_func(params, ansatz, hamiltonian, estimator):
    """Return estimate of energy from estimator

    Parameters:
        params (ndarray): Array of ansatz parameters
        ansatz (QuantumCircuit): Parameterized ansatz circuit
        hamiltonian (SparsePauliOp): Operator representation of Hamiltonian
        estimator (EstimatorV2): Estimator primitive instance
        cost_history_dict: Dictionary for storing intermediate results

    Returns:
        float: Energy estimate
    """
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")

    return energy

# %%
x0 = 2 * np.pi * np.random.random(num_params)
x0
# Out:
# array([4.89874399, 3.92083493, 4.43025277, 5.88012205])

# %%
with Session(backend=backend) as session:
    estimator = Estimator(session=session)
    estimator.options.default_shots = 200

    res = minimize(
        cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
    )
# Out:
# Iters. done: 37 [Current cost: -0.07356534725454364]
# Iters. done: 38 [Current cost: -0.08047969932465793]
# Iters. done: 39 [Current cost: 0.23770939815518904]
# Iters. done: 40 [Current cost: 0.3358681036181487]
# Iters. done: 41 [Current cost: -0.1424013866189963]
# Iters. done: 42 [Current cost: -0.4847659152352847]
# Iters. done: 43 [Current cost: -0.3399984190229691]
# Iters. done: 44 [Current cost: -0.46269767461283856]
# Iters. done: 45 [Current cost: -0.48460965563623726]
# Iters. done: 46 [Current cost: -0.4562503148758088]
# Iters. done: 47 [Current cost: -0.3719946356248453]
# Iters. done: 48 [Current cost: -0.4684387819600136]
# Iters. done: 49 [Current cost: -0.19463077406247456]
# Iters. done: 50 [Current cost: -0.4952262195392989]
# Iters. done: 51 [Current cost: -0.3527875715904274]
# Iters. done: 52 [Current cost: -0.5126912982025136]
# Iters. done: 53 [Current cost: -0.31891986825294116]
# Iters. done: 54 [Current cost: -0.4097730768638519]
# Iters. done: 55 [Current cost: -0.3775498309711591]
# Iters. done: 56 [Current cost: -0.3887781050648281]
# Iters. done: 57 [Current cost: -0.4715832353276739]
# Iters. done: 58 [Current cost: -0.474891836381175]
# Iters. done: 59 [Current cost: -0.42295535200202655]
# Iters. done: 60 [Current cost: -0.33562725512673]
# Iters. done: 61 [Current cost: -0.4426519690064158]
# Iters. done: 62 [Current cost: -0.3423034589270874]
# Iters. done: 63 [Current cost: -0.33227517330395073]
# Iters. done: 64 [Current cost: -0.3478849067439178]
# Iters. done: 65 [Current cost: -0.44275190083970933]
# Iters. done: 66 [Current cost: -0.39048061870821926]
# Iters. done: 67 [Current cost: -0.35000826841957533]
# Iters. done: 68 [Current cost: -0.4043573287376857]
# Iters. done: 69 [Current cost: -0.3028905331474565]
# Iters. done: 70 [Current cost: -0.268360814557879]
# Iters. done: 71 [Current cost: -0.17079660736227267]
# Iters. done: 72 [Current cost: -0.3511894757381425]
# capi_return is NULL
# Call-back cb_calcfc_in__cobyla__user__routines failed.
# ---------------------------------------------------------------------------
# IBMRuntimeError                           Traceback (most recent call last)
# Cell In[17], line 5
#       2 estimator = Estimator(session=session)
#       3 estimator.options.default_shots = 200
# ----> 5 res = minimize(
#       6     cost_func,
#       7     x0,
#       8     args=(ansatz_isa, hamiltonian_isa, estimator),
#       9     method="cobyla",
#      10 )
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_minimize.py:719, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     716     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     717                         **options)
#     718 elif meth == 'cobyla':
# --> 719     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     720                            bounds=bounds, **options)
#     721 elif meth == 'slsqp':
#     722     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     723                           constraints, callback=callback, **options)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:293, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     290         callback(np.copy(x))
#     292 info = np.zeros(4, np.float64)
# --> 293 xopt, info = cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     294                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     295                               dinfo=info, callback=wrapped_callback)
#     297 if info[3] > catol:
#     298     # Check constraint violation
#     299     info[0] = 4
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:281, in _minimize_cobyla.<locals>.calcfc(x, con)
#     280 def calcfc(x, con):
# --> 281     f = sf.fun(x)
#     282     i = 0
#     283     for size, c in izip(cons_lengths, constraints):
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:278, in ScalarFunction.fun(self, x)
#     276 if not np.array_equal(x, self.x):
#     277     self._update_x_impl(x)
# --> 278 self._update_fun()
#     279 return self.f
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# Cell In[13], line 21, in cost_func(params, ansatz, hamiltonian, estimator)
#       8 """Return estimate of energy from estimator
#       9
#      10 Parameters:
#    (...)
#      18     float: Energy estimate
#      19 """
#      20 pub = (ansatz, [hamiltonian], [params])
# ---> 21 result = estimator.run(pubs=[pub]).result()
#      22 energy = result[0].data.evs[0]
#      24 cost_history_dict["iters"] += 1
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/estimator.py:151, in EstimatorV2.run(self, pubs, precision)
#     137 """Submit a request to the estimator primitive.
#     138
#     139 Args:
#    (...)
#     148
#     149 """
#     150 coerced_pubs = [EstimatorPub.coerce(pub, precision) for pub in pubs]
# --> 151 return self._run(coerced_pubs)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/base_primitive.py:163, in BasePrimitiveV2._run(self, pubs)
#     160 logger.info("Submitting job using options %s", primitive_options)
#     162 if self._session:
# --> 163     return self._session.run(
#     164         program_id=self._program_id(),
#     165         inputs=primitive_inputs,
#     166         options=runtime_options,
#     167         callback=options_dict.get("environment", {}).get("callback", None),
#     168         result_decoder=DEFAULT_DECODERS.get(self._program_id()),
#     169     )
#     171 if self._backend:
#     172     runtime_options["backend"] = self._backend
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/session.py:43, in _active_session.<locals>._wrapper(self, *args, **kwargs)
#      41 if not self._active:
#      42     raise RuntimeError("The session is closed.")
# ---> 43 return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/session.py:201, in Session.run(self, program_id, inputs, options, callback, result_decoder)
#     198 options["backend"] = self._backend
#     200 if isinstance(self._service, QiskitRuntimeService):
# --> 201     job = self._service.run(
#     202         program_id=program_id,  # type: ignore[arg-type]
#     203         options=options,
#     204         inputs=inputs,
#     205         session_id=self._session_id,
#     206         start_session=False,
#     207         callback=callback,
#     208         result_decoder=result_decoder,
#     209     )
#     211     if self._backend is None:
#     212         self._backend = job.backend()
#
# File ~/anaconda3/envs/qiskit-1-2/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:884, in QiskitRuntimeService.run(self, program_id, inputs, options, callback, result_decoder, session_id, start_session)
#     882     if ex.status_code == 404:
#     883         raise RuntimeProgramNotFound(f"Program not found: {ex.message}") from None
# --> 884     raise IBMRuntimeError(f"Failed to run program: {ex}") from None
#     885 backend = (
#     886     self.backend(name=response["backend"], instance=hgp_name)
#     887     if response["backend"]
#     888     else qrt_options.get_backend_name()
#     889 )
#     891 if version == 2:
#
# IBMRuntimeError: 'Failed to run program: \'400 Client Error: Bad Request for url: https://api.quantum.ibm.com/runtime/jobs. {"errors":[{"code":1217,"message":"Session has been closed.","solution":"Reduce time between submitting subsequent jobs in a session.","more_info":"https://docs.quantum-computing.ibm.com/errors"}]}\''

# %%
cost_history_dict
plt.plot(cost_history_dict['cost_history'])

# %%
cost_history_dict
plt.plot(cost_history_dict['cost_history'])

# %% [markdown]
# ## Step 4: Post-process, return result in classical format.

# %%
all(cost_history_dict["prev_vector"] == res.x)

# %%
cost_history_dict["iters"] == res.nfev

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %%
cost_history_dict
# Out:
# {'prev_vector': array([3.05888996, 4.43727613, 5.39903657, 5.66676143, 3.91592233,
#         4.00972591, 4.42010001, 2.20419641, 1.54907842, 4.74382172,
#         1.6739801 , 4.65247405, 5.86036756, 4.70397595, 0.87260049,
#         1.27107314]),
#  'iters': 20,
#  'cost_history': [0.14922586116758643,
#   -0.11612803571621408,
#   0.07002776280206445,
#   -0.13386988850633055,
#   -0.3302387656462088,
#   -0.10234731983003965,
#   -0.13772207900026967,
#   -0.45905039527309566,
#   -0.445916509386791,
#   -0.36337138067990404,
#   -0.42997434693744946,
#   -0.28915363465327376,
#   -0.35322293062687277,
#   -0.5704129149833769,
#   -0.47988316089181043,
#   -0.46759465876835415,
#   -0.24320415638696258,
#   -0.588662767522721,
#   -0.44708847005466235,
#   -0.5228542313152235]}

# %%
plt.plot(cost_history_dict['cost_history'])
